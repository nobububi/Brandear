# %% [markdown]
# - 再出品回数のカラムを消したり入れたりする
# - スタッキング、アンサンブル
# - 再出品回数で候補を絞る？

# %%
import lightgbm as lgb

# %%
from os.path import dirname
import os
import datetime
from dateutil.relativedelta import relativedelta
import sys

import pandas as pd
import swifter
import numpy as np
import matplotlib.pyplot as plt
import lightgbm as lgb

# %%
pd.set_option('display.max_columns', 200)

# %%
# %reload_ext autoreload
import brandear_est as be

# %%
SUB_DIR = os.path.join(os.getcwd(), "../../data/submit/")
IMD_DIR = os.path.join(os.getcwd(), "../../data/intermediate/")
INPUT_DIR = os.path.join(os.getcwd(), "../../data/input")

IMD_INPUT_DIR = os.path.join(IMD_DIR, "pickled_inputs")
IMD_EST_WEEKLY_DIR = os.path.join(IMD_DIR, "rank_weekly")
IMD_ARCHIVE_DIR = os.path.join(IMD_DIR, "arc_rank")


dset_to_period = {
    "train": {"oldest": datetime.datetime(2019, 9, 3, 0, 0, 0),
              "newest": datetime.datetime(2019, 9, 10, 0, 0, 0)},
    "valid_for_train": {"oldest": datetime.datetime(2019, 9, 10, 0, 0, 0),
              "newest": datetime.datetime(2019, 9, 17, 0, 0, 0),},    
    "valid_for_sub": {"oldest": datetime.datetime(2019, 9, 17, 0, 0, 0),
              "newest": datetime.datetime(2019, 9, 24, 0, 0, 0),},
    "submission": {"oldest": datetime.datetime(2019, 9, 24, 0, 0, 0),
              "newest": datetime.datetime(2019, 10, 1, 0, 0, 0),},    
}

# %%
# 元データ読み込み
auction = pd.read_pickle(os.path.join(IMD_INPUT_DIR , "auction.pkl"))
watch = pd.read_pickle(os.path.join(IMD_INPUT_DIR , "watch.pkl"))
bid = pd.read_pickle(os.path.join(IMD_INPUT_DIR , "bid.pkl"))
bid_success = pd.read_pickle(os.path.join(IMD_INPUT_DIR , "bid_success.pkl"))
sample_sub = pd.read_csv(os.path.join(INPUT_DIR, "sample_submission.csv"))
sub_users = sample_sub[["KaiinID"]].drop_duplicates()

# ブランド作成日
brand = be.read_csv(os.path.join(INPUT_DIR , "brand.csv"))
# itemcolorid付与(色の大分類)
color = be.read_csv(os.path.join(INPUT_DIR , "color.csv"))
# カテゴリーid,itemdailID付与のためのItemShouID付与
genre = be.read_csv(os.path.join(INPUT_DIR , "genre.csv"))
# itemshowID,itemdailID付与
itemshou = be.read_csv(os.path.join(INPUT_DIR , "itemshou.csv"))
# itemlineID付与
line = be.read_csv(os.path.join(INPUT_DIR , "line.csv"))
# 会員登録日、生年月日付与
kaiin = be.read_csv(os.path.join(INPUT_DIR , "kaiin.csv"))
# 入荷お知らせ
nyuuka_oshirase = be.read_csv(os.path.join(INPUT_DIR , "nyuuka_oshirase.csv"))
# 検索履歴
search_log = be.read_csv(os.path.join(INPUT_DIR , "search_log.tsv"), sep="\t")
# Out:
# Mem. usage decreased to  0.32 Mb (15.0% reduction)
# Mem. usage decreased to  0.01 Mb (32.2% reduction)
# Mem. usage decreased to  0.00 Mb (45.4% reduction)
# Mem. usage decreased to  0.00 Mb (33.4% reduction)
# Mem. usage decreased to  0.01 Mb (41.3% reduction)
# Mem. usage decreased to  5.83 Mb (31.2% reduction)
# Mem. usage decreased to 12.62 Mb (43.7% reduction)
# /Users/nobuyuki.ishida/.pyenv/versions/3.7.5/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3242: DtypeWarning: Columns (10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Mem. usage decreased to 872.24 Mb (40.6% reduction)

# %%
# オークション情報拡充
def rename(df, prefix):
    target_columns = ["ModifyDate", "CreateDate"]
    for target_column in target_columns:
        if target_column in df.columns:
            df.rename(columns={target_column: prefix + target_column}, inplace=True)
    return df

itemshou = rename(itemshou, prefix="ItemShow")
genre = rename(genre, prefix="Genre")
brand = rename(brand, prefix="Brand")
color = rename(color, prefix="Color")
line = rename(line, prefix="Line")
kaiin = rename(kaiin, prefix="Kaiin")

genre_mst = (
    genre[["GenreID", "ItemShouID", "CategoryID"]]
    .merge(itemshou[["ItemShouID", "ItemDaiID"]], on="ItemShouID", how="inner")
)

auction_mst = (
    auction
    .merge(genre_mst, on="GenreID", how="left")
    .merge(brand[["BrandID", "BrandCreateDate"]], on="BrandID", how="left")    
    .merge(color[["ColorID", "ItemColorID"]], on="ColorID", how="left")    
    .merge(line[["LineID", "ItemLineID", "LineCreateDate"]], on="LineID", how="left")        
    .fillna(0)
)
auction_mst = be.to_datetime(auction_mst[sorted(list(auction_mst.columns))])

# %%
# kaiin["KaiinCreateDate"] = pd.to_datetime(kaiin["KaiinCreateDate"], format='%Y-%m-%d %H:%M:%S')
# search_log["TourokuTime"] = pd.to_datetime(search_log["TourokuTime"], format='%Y-%m-%d %H:%M:%S')
# nyuuka_oshirase = be.to_datetime(nyuuka_oshirase)
# search_log = be.to_datetime(search_log)

# %%
def extract_target_actions(watch, bid, period):
    watch_actioned = (
        watch.loc[(watch["TourokuDate"] >= period["oldest"]) & (watch["TourokuDate"] < period["newest"]),
                  ["KaiinID", "AuctionID"]]
    )
    bid_actioned = (
        bid.loc[(bid["ShudouNyuusatsuDate"] >= period["oldest"]) & (bid["ShudouNyuusatsuDate"] < period["newest"]),
                ["KaiinID", "AuctionID"]]
    )
    # 学習用データの際は正解データを作成する
    watch_actioned["watch_actioned"] = 1
    bid_actioned["bid_actioned"] = 1

    target_actions = (
        watch_actioned
        .merge(bid_actioned, on=["KaiinID", "AuctionID"], how="outer")
        .drop_duplicates()
        .fillna(0)
    )

    return target_actions


def arrange_dtime_condition(watch, bid, bid_success, auction, period):
    retval = (
        watch[watch["TourokuDate"] <= period["oldest"]],
        bid[bid["ShudouNyuusatsuDate"] <= period["oldest"]],
        bid_success[bid_success["RakusatsuDate"] < period["oldest"]],        
        auction[auction["CreateDate"] < period["newest"]]        
    )
    return retval

def arrange_inputs(watch, bid, bid_success, auction, period):
    watch_t_arranged, bid_t_arranged, bid_success_t_arranged, auction_arranged = (
        arrange_dtime_condition(watch=watch, bid=bid, bid_success=bid_success,auction=auction, period=period)
    )
    
    retval =  (
        watch_t_arranged.merge(auction, on="AuctionID", how="left"),
        bid_t_arranged.merge(auction, on="AuctionID", how="left"),
        bid_success_t_arranged.merge(auction, on="AuctionID", how="left"),
        auction_arranged
    )
    return retval


def sort_columns(df):
    return df[sorted(list(df.columns))]

def extract_similar_aucs(target_users, auction, actions,):
    similar_aucs = (
        actions.merge(target_users, on="KaiinID")
            .merge(auction, on="ShouhinID")
    )
    return similar_aucs

# %%
def add_user_feature(df, feature_df, col_prefix):
    user_feature = calc_user_feature(feature_df)
    user_feature.columns = [col_prefix + "_KaiinID_" + col if col != "KaiinID" else "KaiinID" for col in user_feature.columns]
    
    return df.merge(user_feature, on="KaiinID", how="left").fillna(0)

def calc_user_feature(feature_df):
    user_feature = (
        feature_df.groupby("KaiinID")
        .agg({
            "AuctionID": {"AuctionID_cnt": "count"},
            "SaishuppinKaisuu": {
                "SaishuppinKaisuu_mean": "mean",
                "SaishuppinKaisuu_sum": "sum"},
            "SankouKakaku": {
                "SankouKakaku_mean": "mean",
                "SankouKakaku_sum": "sum"}
        })
    ).fillna(0)
    user_feature.columns = user_feature.columns.droplevel(0)
    user_feature = user_feature.reset_index()
    return user_feature

def cross_counts(df, col_set, col_name=None):
    if col_name is not None:
        cnt_col_name = col_name
    elif isinstance(col_set, str):
        cnt_col_name = col_set + "_cnt"
    elif isinstance(col_set, list):
        cnt_col_name = "_".join(col_set) + "_cnt"
    cnts = (
        df.groupby(col_set, as_index=False).size().reset_index()
        .rename(columns={0: cnt_col_name})
    )
    return cnts

def extract_recent_data(df, date_col, base_dtime, days):
    oldest_dtime = base_dtime - relativedelta(days=days)
    return df[df[date_col] > oldest_dtime]

# %%
# 特徴量作成の設定
# dataset_types = ["valid_for_train", "valid_for_sub", "submission"]
dataset_types = ["valid_for_train"]
rank_th = 1600
# 商品紐付けとest_rank_weeklyの出力のどちら、または両方使うかのフラグ
inputs_type = ["Shouhin", "rank_weekly"]
rank_weekly_th = 1600

# %%
# %%time

for dset_type in dataset_types:
        
    print(inputs_type)
    
    # データの時系列整理
    watch_arranged, bid_arranged, bid_success_arranged, auction_arranged = (
        arrange_inputs(watch=watch, bid=bid, bid_success=bid_success, auction=auction_mst, period=dset_to_period[dset_type])
    )

    target_actions = extract_target_actions(watch=watch, bid=bid, period=dset_to_period[dset_type])    
    target_users = None
    if dset_type == "submission":
        target_users = sub_users
    else:
        target_users = target_actions[["KaiinID"]].drop_duplicates()
    
    # inputとする候補の分岐
    dataset_base = None    
    # 商品紐付けのみ使う
    if "rank_weekly" not in inputs_type and "Shouhin" in inputs_type:
        dataset_base = extract_similar_aucs(
            target_users=target_users,
             auction=auction_arranged,
             actions=pd.concat([watch_arranged[["KaiinID", "ShouhinID"]], bid_arranged[["KaiinID", "ShouhinID"]]]).drop_duplicates()
        )
    # 両方使う
    elif "rank_weekly" in inputs_type and "Shouhin" in inputs_type:
        ranked_weekly = pd.read_pickle(IMD_EST_WEEKLY_DIR + f"/watch_{dset_type}_{rank_th}.pkl")
        ranked_weekly = ranked_weekly.query(f"rank <= {rank_weekly_th}")
        similar_aucs = extract_similar_aucs(
            target_users=target_users,
             auction=auction_arranged,
             actions=pd.concat([watch_arranged[["KaiinID", "ShouhinID"]], bid_arranged[["KaiinID", "ShouhinID"]]]).drop_duplicates()
        )
        similar_aucs = be.left_anti_join(similar_aucs, bid_success_arranged[["AuctionID"]].drop_duplicates(), "AuctionID", "AuctionID")
        dataset_base = (
            pd.concat([ranked_weekly[["AuctionID", "KaiinID"]], similar_aucs[["AuctionID", "KaiinID"]]]).drop_duplicates()
        )
        
#         dataset_base = dataset_base.sample(frac=0.00001)
    else:
        raise ValueError()
    
    if "targets" in inputs_type:
        dataset_base = pd.concat([dataset_base, target_actions[["KaiinID", "AuctionID"]]], sort=False).drop_duplicates()
        
    # 正解付与
    dataset_base = dataset_base.merge(target_actions, on=["KaiinID", "AuctionID"], how="left").fillna(0)
    
    # オークション情報付与
    dataset_base_a = dataset_base.merge(
        auction_arranged[[col for col in auction_arranged.columns if not col in dataset_base.columns] + ["AuctionID"]],
        on="AuctionID", how="left"
    )

    dataset_base_a = sort_columns(dataset_base_a)
    
    # クロス集計
    w_cate_col = ["AuctionID", "BrandID", "ItemShouID", "ShouhinID"]
    b_cate_col = ["AuctionID", "BrandID", "ItemShouID", "ShouhinID"]
    def add_cate_with_user(cate_col):
        cate_with_user = [["KaiinID", col] for col in cate_col]
        return cate_col + cate_with_user
    
    w_cnt_colsets = add_cate_with_user(w_cate_col)
    b_cnt_colsets = add_cate_with_user(b_cate_col)

    dataset_base_cwb = dataset_base_a

    cross_confs = ([
        [watch_arranged, "watch", w_cnt_colsets],
        [bid_arranged, "bid", b_cnt_colsets]
    ])
    
    for cross_conf in cross_confs:    
        dataset_base_cwb = be.add_cross_counts(
            df=dataset_base_cwb, feature_df=cross_conf[0], prefix=cross_conf[1], col_sets=cross_conf[2]
        )
    
    # ユーザーの特徴量付与
    # 何回watch/bid/successしたか
    # 再出品回数、価格の平均、分散、今回との割合
    dataset_base_u = dataset_base_cwb

    dataset_base_u = add_user_feature(df=dataset_base_u, feature_df=watch_arranged, col_prefix="watch")

    for col in ["SaishuppinKaisuu", "SankouKakaku"]:
        dataset_base_u[f"watch_KaiinID_rate_mean_to_{col}"] = (
            dataset_base_u[f"watch_KaiinID_{col}_mean"] / dataset_base_u[col]
        )    
    
    # 時間系の特緒量付与
    oldest_dtime = dset_to_period[dset_type]["oldest"]
    
    def calc_timedelta(df, dtime_col, delta_col):
        df[delta_col] = df[dtime_col].swifter.apply(lambda d: (oldest_dtime - d).days)
    
    calc_timedelta(dataset_base_u, "CreateDate", "Auction_elapsed_days")
    calc_timedelta(watch_arranged, "TourokuDate", "watch_elapsed_day")    
        
    def agg_time_feature(df, agg_key, na_value):
        time_agg = df.groupby(agg_key).agg({
            "watch_elapsed_day": {
                f"{agg_key}_watch_elapsed_day_min": "min"
            }    
        }).fillna(na_value)
        time_agg.columns = time_agg.columns.droplevel(0)
        time_agg = time_agg.reset_index()
        return time_agg
        
    w_k_d = agg_time_feature(df=watch_arranged, agg_key="KaiinID", na_value=999)
    w_a_d = agg_time_feature(df=watch_arranged, agg_key="AuctionID", na_value=999)
    
    dataset_base_u = (
        dataset_base_u.merge(w_k_d, on="KaiinID", how="left").fillna(999)
        .merge(w_a_d, on="AuctionID", how="left").fillna(0)
    )
    
    # お気に入り合計に対する該当オークションのお気に入り数

    dataset_base_b = dataset_base_u
    dataset_base_b["watch_BrandID_KaiinID_rate"] = (
        dataset_base_b["watch_KaiinID_BrandID_cnt"] / dataset_base_b["watch_KaiinID_AuctionID_cnt_y"]
    ).fillna(0)

    dataset_base_b["watch_ItemShouID_KaiinID_rate"] = (
        dataset_base_b["watch_KaiinID_ItemShouID_cnt"] / dataset_base_b["watch_KaiinID_AuctionID_cnt_y"]
    ).fillna(0)

    for cat_col in ["BrandID", "ItemShouID"]:
        brand_ave = (
            auction_arranged[[cat_col, "SankouKakaku"]].groupby(cat_col, as_index=False).mean()
            .rename(columns={"SankouKakaku": f"{cat_col}_SankouKakaku"})
        )
        dataset_base_b = dataset_base_b.merge(brand_ave, on=cat_col, how="left")
        dataset_base_b[f"SankouKakaku_rate_to_{cat_col}"] = (
            dataset_base_b["SankouKakaku"] / dataset_base_b[f"{cat_col}_SankouKakaku"]
        )

#     # 推定の際に業者を区分するための数値
#     watch_cnt = watch_arranged.groupby("KaiinID").size().reset_index().rename(columns={0: "watch_cnt"})
#     bid_cnt = bid_arranged.groupby("KaiinID").size().reset_index().rename(columns={0: "bid_cnt"})
#     dataset_base_b = (
#         be.left_anti_join(
#             dataset_base_b.merge(watch_cnt, on="KaiinID", how="left")
#             .merge(bid_cnt, on="KaiinID", how="left")
#             .fillna(0),
#             bid_success_arranged[["AuctionID"]], "AuctionID", "AuctionID"
#         )
#     )
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M")
    be.df2pkl(dataset_base_b, IMD_ARCHIVE_DIR, f"{dset_type}_feature_{rank_th}_{now}.pkl")
# Out:
# ['Shouhin', 'rank_weekly']
# ##################
# start cross count
# ['AuctionID', 'BrandID', 'ItemShouID', 'ShouhinID', ['KaiinID', 'AuctionID'], ['KaiinID', 'BrandID'], ['KaiinID', 'ItemShouID'], ['KaiinID', 'ShouhinID']]
# AuctionID
# BrandID
# ItemShouID
# ShouhinID
# ['KaiinID', 'AuctionID']
# ['KaiinID', 'BrandID']
# ['KaiinID', 'ItemShouID']
# ['KaiinID', 'ShouhinID']
# ##################
# start cross count
# ['AuctionID', 'BrandID', 'ItemShouID', 'ShouhinID', ['KaiinID', 'AuctionID'], ['KaiinID', 'BrandID'], ['KaiinID', 'ItemShouID'], ['KaiinID', 'ShouhinID']]
# AuctionID
# BrandID
# ItemShouID
# ShouhinID
# ['KaiinID', 'AuctionID']
# ['KaiinID', 'BrandID']
# ['KaiinID', 'ItemShouID']
# ['KaiinID', 'ShouhinID']
# /Users/nobuyuki.ishida/.pyenv/versions/3.7.5/lib/python3.7/site-packages/pandas/core/groupby/generic.py:1455: FutureWarning: using a dict with renaming is deprecated and will be removed
# in a future version.
#
# For column-specific groupby renaming, use named aggregation
#
#     >>> df.groupby(...).agg(name=('column', aggfunc))
#
#   return super().aggregate(arg, *args, **kwargs)
# HBox(children=(FloatProgress(value=0.0, description='Dask Apply', max=16.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Dask Apply', max=16.0, style=ProgressStyle(description_wi…
# /Users/nobuyuki.ishida/.pyenv/versions/3.7.5/lib/python3.7/site-packages/pandas/core/groupby/generic.py:1455: FutureWarning: using a dict with renaming is deprecated and will be removed
# in a future version.
#
# For column-specific groupby renaming, use named aggregation
#
#     >>> df.groupby(...).agg(name=('column', aggfunc))
#
#   return super().aggregate(arg, *args, **kwargs)
# CPU times: user 3min 25s, sys: 2min 40s, total: 6min 6s
# Wall time: 8min 15s

# %%
def stack_target_actions(target_actions):
    watch_target = target_actions.query("(watch_actioned == 1)")[["KaiinID", "AuctionID"]]
    bid_target = target_actions.query("(bid_actioned == 1)")[["KaiinID", "AuctionID"]]
    watch_target["score"] = 1
    bid_target["score"] = 2
    stacked_target_actions = pd.concat([watch_target, bid_target], sort=False)
    return stacked_target_actions

def dcg_at_k(r, k):
    r = np.asfarray(r)[:k]
    return np.sum((2 ** r - 1) / np.log2(np.arange(2, r.size + 2)))


def ndcg_at_k(r, k):
    dcg_max = dcg_at_k(sorted(r, reverse=True), k)
    if not dcg_max:
        return 0.
    return dcg_at_k(r, k) / dcg_max


def calc_ndcg(y_true, y_pred, k=20):
    y_pred_cp = y_pred.copy()

    actione_true = stack_target_actions(y_true)
    actione_true["rank"] = 100

    y_pred_cp['rank'] = y_pred_cp.groupby('KaiinID')['AuctionID'].cumcount()

    scored_pred = (
        y_pred_cp.merge(actione_true[["KaiinID", "AuctionID", "score"]], on=["KaiinID", "AuctionID"],
                        how="left").fillna(0))

    unchoiced_actiones = (
        be.left_anti_join(actione_true, y_pred_cp, ["KaiinID", "AuctionID"], ["KaiinID", "AuctionID"]))

    scored_actiones = (
        pd.concat([scored_pred, unchoiced_actiones], sort=False)
            .sort_values(["KaiinID", "rank"], ascending=["True", "True"]))

    dcgs = scored_actiones.groupby("KaiinID")["score"].apply(lambda s: ndcg_at_k(s.tolist(), k=20))
#     ndcg = dcgs.mean()

    return dcgs

# %%
vt_dataset_base = pd.read_pickle(IMD_ARCHIVE_DIR + "/valid_for_train_feature_1600_202002231640.pkl")
# vs_dataset_base = pd.read_pickle(IMD_ARCHIVE_DIR + "/valid_for_sub_feature_1600_202002231500.pkl")
# sub_dataset_base = pd.read_pickle(IMD_ARCHIVE_DIR + "/submission_feature_1600_202002231509.pkl")

# %%
add_confs = {
    "valid_for_train": vt_dataset_base
#     "valid_for_sub": vs_dataset_base,
#     "submission": sub_dataset_base
}
for dset_type, dataset_base  in add_confs.items():
    print(dset_type)
    watch_arranged, bid_arranged, bid_success_arranged, auction_arranged = (
        arrange_inputs(watch=watch, bid=bid, bid_success=bid_success, auction=auction, period=dset_to_period[dset_type])
    )
    watch_cnt = watch_arranged.groupby("KaiinID").size().reset_index().rename(columns={0: "watch_cnt"})
    bid_cnt = bid_arranged.groupby("KaiinID").size().reset_index().rename(columns={0: "bid_cnt"})
    dataset_base = dataset_base.merge(bid_cnt, on="KaiinID", how="left").merge(watch_cnt, on="KaiinID", how="left").fillna(0)
    now = datetime.datetime.now().strftime("%Y%m%d%H%M")
    be.df2pkl(dataset_base, IMD_ARCHIVE_DIR, f"{dset_type}_feature_{rank_th}_cnts_{now}.pkl")
# Out:
# valid_for_train

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split


class DataSet:
    """
    モデルのインプットになるデータをクラス化。
    データ側で持っておくべき情報を保持する。
    """

    def __init__(self, data, drop_cols, target_col):
        """
        data:
            データ
        drop_cols:
            予測の際削除するカラム。
        target:
            予測対象のカラム。
        """
        self.data = data.copy()
        self.drop_cols = drop_cols
        self.target_col = target_col
        self.pred = None

    def drop(self):
        """予測用に不要カラムを削除"""
        drop_cols = [col for col in self.drop_cols + [self.target_col] + ["pred"]
                     if col in self.data]
        return self.data.drop(drop_cols, axis=1)

    def get_target(self):
        """予測対象データを取得"""
        return self.data[self.target_col]

    def set_pred(self, pred):
        """予測値を保持"""
        self.data["pred"] = pred

    def add_target_encode(self, cat_col):
        # 学習データの変換後の値を格納する配列を準備
        buf = np.repeat(np.nan, self.data.shape[0])

        # 学習データを分割
        kf = KFold(n_splits=4, shuffle=True, random_state=72)
        if isinstance(cat_col, str):
            for idx_1, idx_2 in kf.split(self.data):
                # out-of-foldで各カテゴリにおける目的変数の平均を計算
                target_mean = self.data.iloc[idx_1][[cat_col, self.target_col]].groupby(cat_col)[self.target_col].mean()
                # 変換後の値を一時配列に格納
                buf[idx_2] = self.data[cat_col].iloc[idx_2].map(target_mean)
            # 変換後のデータで元の変数を置換
            self.data[cat_col + "_target_mean"] = buf

        elif isinstance(cat_col, list):
            for idx_1, idx_2 in kf.split(self.data):
                # out-of-foldで各カテゴリにおける目的変数の平均を計算
                target_mean = self.data.iloc[idx_1][cat_col + [self.target_col]].groupby(cat_col, as_index=False)[
                    self.target_col].mean()
                # 変換後の値を一時配列に格納
                #                 import pdb;pdb.set_trace()
                buf[idx_2] = self.data[cat_col].iloc[idx_2].merge(target_mean, on=cat_col, how="left").fillna(0)[
                    "watch_actioned"]
                # 変換後のデータで元の変数を置換
                self.data["_".join(cat_col) + "_target_mean"] = buf

    @classmethod
    def under_sampling(cls, dataset, rate=10):
        positive_targets = dataset.data[dataset.data[dataset.target_col] == 1]
        sampled_negative = (
            dataset.data[dataset.data[dataset.target_col] != 1]
                .sample(n=positive_targets.shape[0] * rate)
        )
        sampled_data = pd.concat([positive_targets, sampled_negative])
        return cls(data=sampled_data, drop_cols=dataset.drop_cols, target_col=dataset.target_col)

    @classmethod
    def train_test_split(cls, dataset, test_size=0.2):
        train_data, test_data = train_test_split(dataset.data)
        return (cls(data=train_data, drop_cols=dataset.drop_cols, target_col=dataset.target_col),
                cls(data=test_data, drop_cols=dataset.drop_cols, target_col=dataset.target_col))

    @classmethod
    def gen_from_pkls(cls, paths, drop_cols, target_col):
        return [cls(data=pd.read_pickle(path).fillna(0), drop_cols=drop_cols, target_col=target_col)
                for path in paths]


def target_encode_for_test(train_dataset, test_dataset, cat_col):
    if isinstance(cat_col, str):
        test_dataset.data[f"{cat_col}_target_mean"] = (
            test_dataset.data[cat_col].map(
                train_dataset.data[[cat_col, train_dataset.target_col]].groupby(cat_col)[
                    train_dataset.target_col].mean()
            )
        )
    elif isinstance(cat_col, list):
        test_dataset.data = (
            test_dataset.data.merge(
                train_dataset.data[cat_col + [train_dataset.target_col]]
                    .groupby(cat_col, as_index=False)[train_dataset.target_col].mean().rename(
                    columns={train_dataset.target_col: "_".join(cat_col) + "_target_mean"}),
                on=cat_col, how="left"
            ).fillna(0)
        )

# %%
# vt_dataset_base = pd.read_pickle(IMD_ARCHIVE_DIR + "/valid_for_train_feature_1600_cnts_202002231645.pkl")
vs_dataset_base = pd.read_pickle(IMD_ARCHIVE_DIR + "/valid_for_sub_feature_1600_cnts_202002231516.pkl")
sub_dataset_base = pd.read_pickle(IMD_ARCHIVE_DIR + "/submission_feature_1600_cnts_202002231517.pkl")

# %%
def calc_timedelta(df, dtime_col, delta_col, oldest_dtime):
    df[delta_col] = df[dtime_col].swifter.apply(lambda d: (oldest_dtime - d).days)


confs = [["valid_for_sub", vs_dataset_base], ["valid_for_sub", sub_dataset_base]]
for dset_type, dataset_base in confs:
    # データの時系列整理
    watch_arranged, bid_arranged, bid_success_arranged, auction_arranged = (
        arrange_inputs(watch=watch, bid=bid, bid_success=bid_success, auction=auction_mst, period=dset_to_period[dset_type])
    )

    calc_timedelta(watch_arranged, "TourokuDate", "watch_elapsed_days", dset_to_period[dset_type]["oldest"])
    watch_interval = (
        watch_arranged[["KaiinID", "watch_elapsed_days"]]
        .sort_values(["KaiinID", "watch_elapsed_days"])
        .groupby("KaiinID")["watch_elapsed_days"].apply(lambda s: (s - s.shift()).mean())
    )    
    dataset_base["watch_interval"] = dataset_base["KaiinID"].map(watch_interval).fillna(999)
    
    calc_timedelta(bid_arranged, "ShudouNyuusatsuDate", "bid_elapsed_days", dset_to_period[dset_type]["oldest"])
    bid_interval = (
        bid_arranged[["KaiinID", "bid_elapsed_days"]]
        .sort_values(["KaiinID", "bid_elapsed_days"])
        .groupby("KaiinID")["bid_elapsed_days"].apply(lambda s: (s - s.shift()).mean())
    )    
    dataset_base["bid_interval"] = dataset_base["KaiinID"].map(bid_interval).fillna(999)
    
    
    dataset_base["left_day_interval_rate"] = (
        dataset_base["KaiinID_watch_elapsed_day_min"] / dataset_base["Auction_elapsed_days"]
    ).fillna(0)
    dataset_base["left_day_watch_interval_rate"] = (
        dataset_base["watch_interval"] / dataset_base["Auction_elapsed_days"]
    ).fillna(0)
    dataset_base["left_day_bid_interval_rate"] = (
        dataset_base["bid_interval"] / dataset_base["Auction_elapsed_days"]
    ).fillna(0)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Dask Apply', max=16.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Dask Apply', max=16.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Dask Apply', max=16.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Dask Apply', max=16.0, style=ProgressStyle(description_wi…

# %%
auc_foreign_ids = ["BrandID", "CategoryID", "ColorID", "ConditionID", "DanjobetsuID", "GenreGroupID",
            "GenreID", "ItemColorID", "ItemDaiID", "ItemLineID", "ItemShouID", "LineID", "ShouhinID", "ShouhinShubetsuID"]
drop_cols = (
    ["KaiinID", "AuctionID", "BrandCreateDate", "LineCreateDate", "CreateDate", "rank", "watch_actioned", "bid_actioned", "watch_cnt", "bid_cnt"]
    + auc_foreign_ids
)

# vt_private_dataset = DataSet(data=vt_dataset_base.query("(watch_cnt < 1000) & (bid_cnt < 50)"),
#                                 drop_cols=drop_cols, target_col="watch_actioned")
# vt_business_dataset = DataSet(data=vt_dataset_base.query("(watch_cnt >= 1000) | (bid_cnt >= 50)"),
#                                 drop_cols=drop_cols, target_col="watch_actioned")

vs_private_dataset = DataSet(data=vs_dataset_base.query("(watch_cnt < 1000) & (bid_cnt < 50)"),
                                drop_cols=drop_cols, target_col="watch_actioned")
vs_business_dataset = DataSet(data=vs_dataset_base.query("(watch_cnt >= 1000) | (bid_cnt >= 50)"),
                                drop_cols=drop_cols, target_col="watch_actioned")

sub_private_dataset = be.DataSet(data=sub_dataset_base.query("(watch_cnt < 1000) & (bid_cnt < 50)"),
                                drop_cols=drop_cols, target_col="watch_actioned")
sub_business_dataset = be.DataSet(data=sub_dataset_base.query("(watch_cnt >= 1000) | (bid_cnt >= 50)"),
                                drop_cols=drop_cols, target_col="watch_actioned")

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn import preprocessing

# %%
from functools import reduce

# %%
from sklearn.linear_model import LogisticRegression

class LogBinaryClassifier():
    def __init__(self, params=None):
        self.model = None

    def train(self, train_dataset, valid_dataset=None, desc=False):
        mm = preprocessing.MinMaxScaler()
        self.model = LogisticRegression(random_state=1, max_iter=200).fit(
            X=mm.fit_transform(np.array(train_dataset.drop().replace(np.inf,np.nan).fillna(0))),
            y=train_dataset.get_target().replace(np.inf,np.nan).fillna(0)
        )

    def predict(self, dataset):
        return self.model.predict_proba(dataset.drop().replace(np.inf,np.nan).fillna(0))[:, 1]

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
class RfcBinaryClassifier():
    def __init__(self, params=None):
        self.model = None

    def train(self, train_dataset, valid_dataset=None, desc=False):
        self.model = RFC(random_state=1, n_jobs=-1).fit(
            X=train_dataset.drop().replace(np.inf,np.nan).fillna(0),
            y=train_dataset.get_target()
        )

    def predict(self, dataset):
        return self.model.predict_proba(dataset.drop().replace(np.inf,np.nan).fillna(0))[:, 1]

# %%
# %%time

datasets_conf = {
    "private": {"in_train_dataset": vs_private_dataset, "sub_dataset": sub_private_dataset,
    "sample_posi": 4, "sample_nega": 400},
    "business": {"in_train_dataset": vs_business_dataset, "sub_dataset": sub_business_dataset,
    "sample_posi": 40, "sample_nega": 600}
}

params = {
    'objective': 'lambdarank',
    'metric': 'ndcg',
    "ndcg_at": 20,
    "nround": 500,
    "learning_rate": 0.01,
    "max_depth": 6,
    "num_leaves": 127
}

ensemble_pri_buf = {}
ensemble_bus_buf = {}
ensemble_buf = {
    "private": ensemble_pri_buf, "business": ensemble_bus_buf
}

rank_buf = {}

for dataset_name, dataset_conf in datasets_conf.items():

    in_train_dataset = dataset_conf["in_train_dataset"]
    sub_dataset = dataset_conf["sub_dataset"]

    seed_buf = {}
    
    for seed in range(5):
        # train test split
        sampled_train = DataSet(
            pd.concat([
                in_train_dataset.data.query("(watch_actioned == 1) | (bid_actioned == 1)").sample(frac=1)
                .groupby("KaiinID").head(dataset_conf["sample_posi"]),
                in_train_dataset.data.query("(watch_actioned != 1) & (bid_actioned != 1)").sample(frac=1)
                .groupby("KaiinID").head(dataset_conf["sample_nega"]),
            ]),
            drop_cols=train_dataset.drop_cols, target_col=train_dataset.target_col
        )
        # target encoding
        cat_cols = ["BrandID", "ItemShouID", "AuctionID"]
        for cat_col in cat_cols:
            sampled_train.add_target_encode(cat_col=cat_col)

        params["random_state"] = seed
        lgb_rank = be.LgbLambdaLank(params=params)
        lgb_rank.train(train_dataset=sampled_train, desc=True)

        for cat_col in cat_cols:
            be.target_encode_for_test(
                train_dataset=in_train_dataset, test_dataset=sub_dataset, cat_col=cat_col
            )
        
        seed_buf[seed] = lgb_rank.predict(sub_dataset)

    lgb_bin = be.LgbBinaryClassifier()
    lgb_bin.train(train_dataset=sampled_train)
    ensemble_buf[dataset_name]["lgb_bin"] = lgb_bin.predict(dataset=sub_dataset)
                
    rfc_bin = RfcBinaryClassifier()
    rfc_bin.train(train_dataset=sampled_train)
    ensemble_buf[dataset_name]["rfc_bin"] = rfc_bin.predict(dataset=sub_dataset) 
        
    ensemble_buf[dataset_name]["lgb_rank"] = reduce(lambda a,b: a+b, [v for v in seed_buf.values()])
# Out:
# ##################
#                                              importance
# SaishuppinKaisuu                                    170
# SankouKakaku                                         57
# watch_AuctionID_cnt                                 213
# watch_BrandID_cnt                                   310
# watch_ItemShouID_cnt                                102
# watch_ShouhinID_cnt                                 157
# watch_KaiinID_AuctionID_cnt_x                        41
# watch_KaiinID_BrandID_cnt                            68
# watch_KaiinID_ItemShouID_cnt                        124
# watch_KaiinID_ShouhinID_cnt                         131
# bid_AuctionID_cnt                                    82
# bid_BrandID_cnt                                     303
# bid_ItemShouID_cnt                                   87
# bid_ShouhinID_cnt                                    31
# bid_KaiinID_AuctionID_cnt                             0
# bid_KaiinID_BrandID_cnt                              96
# bid_KaiinID_ItemShouID_cnt                           10
# bid_KaiinID_ShouhinID_cnt                             2
# watch_KaiinID_AuctionID_cnt_y                       142
# watch_KaiinID_SaishuppinKaisuu_mean                  38
# watch_KaiinID_SaishuppinKaisuu_sum                  141
# watch_KaiinID_SankouKakaku_mean                     111
# watch_KaiinID_SankouKakaku_sum                       97
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         339
# watch_KaiinID_rate_mean_to_SankouKakaku             217
# Auction_elapsed_days                                420
# KaiinID_watch_elapsed_day_min                       183
# AuctionID_watch_elapsed_day_min                     437
# watch_BrandID_KaiinID_rate                          474
# watch_ItemShouID_KaiinID_rate                       356
# BrandID_SankouKakaku                                112
# SankouKakaku_rate_to_BrandID                        111
# ItemShouID_SankouKakaku                              59
# SankouKakaku_rate_to_ItemShouID                      86
# watch_interval                                       26
# bid_interval                                         32
# left_day_interval_rate                              113
# left_day_watch_interval_rate                        163
# left_day_bid_interval_rate                           93
# BrandID_target_mean                                 106
# ItemShouID_target_mean                              155
# AuctionID_target_mean                               202
# ##################
#
#
# ##################
#                                              importance
# SaishuppinKaisuu                                    180
# SankouKakaku                                         71
# watch_AuctionID_cnt                                 186
# watch_BrandID_cnt                                   370
# watch_ItemShouID_cnt                                137
# watch_ShouhinID_cnt                                 187
# watch_KaiinID_AuctionID_cnt_x                        58
# watch_KaiinID_BrandID_cnt                            89
# watch_KaiinID_ItemShouID_cnt                        108
# watch_KaiinID_ShouhinID_cnt                         130
# bid_AuctionID_cnt                                    83
# bid_BrandID_cnt                                     242
# bid_ItemShouID_cnt                                   37
# bid_ShouhinID_cnt                                    46
# bid_KaiinID_AuctionID_cnt                             0
# bid_KaiinID_BrandID_cnt                              98
# bid_KaiinID_ItemShouID_cnt                           16
# bid_KaiinID_ShouhinID_cnt                            11
# watch_KaiinID_AuctionID_cnt_y                       160
# watch_KaiinID_SaishuppinKaisuu_mean                  46
# watch_KaiinID_SaishuppinKaisuu_sum                  153
# watch_KaiinID_SankouKakaku_mean                      93
# watch_KaiinID_SankouKakaku_sum                       82
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         315
# watch_KaiinID_rate_mean_to_SankouKakaku             165
# Auction_elapsed_days                                421
# KaiinID_watch_elapsed_day_min                       202
# AuctionID_watch_elapsed_day_min                     421
# watch_BrandID_KaiinID_rate                          480
# watch_ItemShouID_KaiinID_rate                       363
# BrandID_SankouKakaku                                116
# SankouKakaku_rate_to_BrandID                         78
# ItemShouID_SankouKakaku                              74
# SankouKakaku_rate_to_ItemShouID                      68
# watch_interval                                       43
# bid_interval                                         34
# left_day_interval_rate                              166
# left_day_watch_interval_rate                        154
# left_day_bid_interval_rate                           82
# BrandID_target_mean                                  95
# ItemShouID_target_mean                              127
# AuctionID_target_mean                               239
# ##################
#
#
# ##################
#                                              importance
# SaishuppinKaisuu                                    197
# SankouKakaku                                         70
# watch_AuctionID_cnt                                 216
# watch_BrandID_cnt                                   278
# watch_ItemShouID_cnt                                 99
# watch_ShouhinID_cnt                                 193
# watch_KaiinID_AuctionID_cnt_x                        80
# watch_KaiinID_BrandID_cnt                           100
# watch_KaiinID_ItemShouID_cnt                        114
# watch_KaiinID_ShouhinID_cnt                         113
# bid_AuctionID_cnt                                    82
# bid_BrandID_cnt                                     324
# bid_ItemShouID_cnt                                   46
# bid_ShouhinID_cnt                                    37
# bid_KaiinID_AuctionID_cnt                             3
# bid_KaiinID_BrandID_cnt                              71
# bid_KaiinID_ItemShouID_cnt                           18
# bid_KaiinID_ShouhinID_cnt                            16
# watch_KaiinID_AuctionID_cnt_y                       162
# watch_KaiinID_SaishuppinKaisuu_mean                  40
# watch_KaiinID_SaishuppinKaisuu_sum                  156
# watch_KaiinID_SankouKakaku_mean                      98
# watch_KaiinID_SankouKakaku_sum                       79
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         291
# watch_KaiinID_rate_mean_to_SankouKakaku             169
# Auction_elapsed_days                                409
# KaiinID_watch_elapsed_day_min                       177
# AuctionID_watch_elapsed_day_min                     456
# watch_BrandID_KaiinID_rate                          489
# watch_ItemShouID_KaiinID_rate                       401
# BrandID_SankouKakaku                                 98
# SankouKakaku_rate_to_BrandID                        101
# ItemShouID_SankouKakaku                              91
# SankouKakaku_rate_to_ItemShouID                      59
# watch_interval                                       37
# bid_interval                                         39
# left_day_interval_rate                              145
# left_day_watch_interval_rate                        150
# left_day_bid_interval_rate                          120
# BrandID_target_mean                                  64
# ItemShouID_target_mean                              149
# AuctionID_target_mean                               200
# ##################
#
#
# ##################
#                                              importance
# SaishuppinKaisuu                                    215
# SankouKakaku                                         60
# watch_AuctionID_cnt                                 228
# watch_BrandID_cnt                                   347
# watch_ItemShouID_cnt                                 75
# watch_ShouhinID_cnt                                 160
# watch_KaiinID_AuctionID_cnt_x                        57
# watch_KaiinID_BrandID_cnt                           125
# watch_KaiinID_ItemShouID_cnt                        112
# watch_KaiinID_ShouhinID_cnt                         125
# bid_AuctionID_cnt                                    90
# bid_BrandID_cnt                                     271
# bid_ItemShouID_cnt                                   26
# bid_ShouhinID_cnt                                    11
# bid_KaiinID_AuctionID_cnt                             0
# bid_KaiinID_BrandID_cnt                              72
# bid_KaiinID_ItemShouID_cnt                           19
# bid_KaiinID_ShouhinID_cnt                             2
# watch_KaiinID_AuctionID_cnt_y                       151
# watch_KaiinID_SaishuppinKaisuu_mean                  58
# watch_KaiinID_SaishuppinKaisuu_sum                  153
# watch_KaiinID_SankouKakaku_mean                      95
# watch_KaiinID_SankouKakaku_sum                       87
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         335
# watch_KaiinID_rate_mean_to_SankouKakaku             198
# Auction_elapsed_days                                424
# KaiinID_watch_elapsed_day_min                       203
# AuctionID_watch_elapsed_day_min                     408
# watch_BrandID_KaiinID_rate                          474
# watch_ItemShouID_KaiinID_rate                       374
# BrandID_SankouKakaku                                125
# SankouKakaku_rate_to_BrandID                         68
# ItemShouID_SankouKakaku                              81
# SankouKakaku_rate_to_ItemShouID                      66
# watch_interval                                       41
# bid_interval                                         45
# left_day_interval_rate                              136
# left_day_watch_interval_rate                        185
# left_day_bid_interval_rate                           65
# BrandID_target_mean                                 108
# ItemShouID_target_mean                              151
# AuctionID_target_mean                               221
# ##################
# ##################
#                                              importance
# SaishuppinKaisuu                                    191
# SankouKakaku                                         60
# watch_AuctionID_cnt                                 246
# watch_BrandID_cnt                                   302
# watch_ItemShouID_cnt                                116
# watch_ShouhinID_cnt                                 166
# watch_KaiinID_AuctionID_cnt_x                        74
# watch_KaiinID_BrandID_cnt                            71
# watch_KaiinID_ItemShouID_cnt                        159
# watch_KaiinID_ShouhinID_cnt                         120
# bid_AuctionID_cnt                                    83
# bid_BrandID_cnt                                     279
# bid_ItemShouID_cnt                                   68
# bid_ShouhinID_cnt                                    50
# bid_KaiinID_AuctionID_cnt                             0
# bid_KaiinID_BrandID_cnt                              84
# bid_KaiinID_ItemShouID_cnt                           28
# bid_KaiinID_ShouhinID_cnt                             7
# watch_KaiinID_AuctionID_cnt_y                       160
# watch_KaiinID_SaishuppinKaisuu_mean                  33
# watch_KaiinID_SaishuppinKaisuu_sum                  160
# watch_KaiinID_SankouKakaku_mean                      97
# watch_KaiinID_SankouKakaku_sum                       86
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         333
# watch_KaiinID_rate_mean_to_SankouKakaku             181
# Auction_elapsed_days                                354
# KaiinID_watch_elapsed_day_min                       197
# AuctionID_watch_elapsed_day_min                     399
# watch_BrandID_KaiinID_rate                          517
# watch_ItemShouID_KaiinID_rate                       429
# BrandID_SankouKakaku                                 87
# SankouKakaku_rate_to_BrandID                        103
# ItemShouID_SankouKakaku                              80
# SankouKakaku_rate_to_ItemShouID                      59
# watch_interval                                       29
# bid_interval                                         56
# left_day_interval_rate                              157
# left_day_watch_interval_rate                        151
# left_day_bid_interval_rate                           58
# BrandID_target_mean                                  82
# ItemShouID_target_mean                              109
# AuctionID_target_mean                               239
# ##################
#
#
# ##################
#                                              importance
# SaishuppinKaisuu                                    317
# SankouKakaku                                         54
# watch_AuctionID_cnt                                 129
# watch_BrandID_cnt                                   247
# watch_ItemShouID_cnt                                 49
# watch_ShouhinID_cnt                                 162
# watch_KaiinID_AuctionID_cnt_x                        83
# watch_KaiinID_BrandID_cnt                           290
# watch_KaiinID_ItemShouID_cnt                        138
# watch_KaiinID_ShouhinID_cnt                         112
# bid_AuctionID_cnt                                    63
# bid_BrandID_cnt                                     222
# bid_ItemShouID_cnt                                   64
# bid_ShouhinID_cnt                                    31
# bid_KaiinID_AuctionID_cnt                             0
# bid_KaiinID_BrandID_cnt                             183
# bid_KaiinID_ItemShouID_cnt                           96
# bid_KaiinID_ShouhinID_cnt                            41
# watch_KaiinID_AuctionID_cnt_y                        39
# watch_KaiinID_SaishuppinKaisuu_mean                  83
# watch_KaiinID_SaishuppinKaisuu_sum                  133
# watch_KaiinID_SankouKakaku_mean                     185
# watch_KaiinID_SankouKakaku_sum                      100
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         331
# watch_KaiinID_rate_mean_to_SankouKakaku             103
# Auction_elapsed_days                                392
# KaiinID_watch_elapsed_day_min                        68
# AuctionID_watch_elapsed_day_min                     515
# watch_BrandID_KaiinID_rate                          268
# watch_ItemShouID_KaiinID_rate                       236
# BrandID_SankouKakaku                                 96
# SankouKakaku_rate_to_BrandID                        201
# ItemShouID_SankouKakaku                             100
# SankouKakaku_rate_to_ItemShouID                      57
# watch_interval                                       76
# bid_interval                                        132
# left_day_interval_rate                              108
# left_day_watch_interval_rate                         62
# left_day_bid_interval_rate                           94
# BrandID_target_mean                                 114
# ItemShouID_target_mean                              124
# AuctionID_target_mean                               292
# ##################
#
#
# ##################
#                                              importance
# SaishuppinKaisuu                                    262
# SankouKakaku                                         67
# watch_AuctionID_cnt                                 114
# watch_BrandID_cnt                                   250
# watch_ItemShouID_cnt                                 54
# watch_ShouhinID_cnt                                 118
# watch_KaiinID_AuctionID_cnt_x                       121
# watch_KaiinID_BrandID_cnt                           248
# watch_KaiinID_ItemShouID_cnt                        160
# watch_KaiinID_ShouhinID_cnt                         118
# bid_AuctionID_cnt                                    72
# bid_BrandID_cnt                                     333
# bid_ItemShouID_cnt                                   35
# bid_ShouhinID_cnt                                    42
# bid_KaiinID_AuctionID_cnt                             1
# bid_KaiinID_BrandID_cnt                             196
# bid_KaiinID_ItemShouID_cnt                           97
# bid_KaiinID_ShouhinID_cnt                            28
# watch_KaiinID_AuctionID_cnt_y                        62
# watch_KaiinID_SaishuppinKaisuu_mean                  96
# watch_KaiinID_SaishuppinKaisuu_sum                  164
# watch_KaiinID_SankouKakaku_mean                     160
# watch_KaiinID_SankouKakaku_sum                       90
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         273
# watch_KaiinID_rate_mean_to_SankouKakaku             102
# Auction_elapsed_days                                405
# KaiinID_watch_elapsed_day_min                        87
# AuctionID_watch_elapsed_day_min                     524
# watch_BrandID_KaiinID_rate                          289
# watch_ItemShouID_KaiinID_rate                       268
# BrandID_SankouKakaku                                 83
# SankouKakaku_rate_to_BrandID                        208
# ItemShouID_SankouKakaku                             114
# SankouKakaku_rate_to_ItemShouID                      80
# watch_interval                                       61
# bid_interval                                        120
# left_day_interval_rate                               80
# left_day_watch_interval_rate                         64
# left_day_bid_interval_rate                          111
# BrandID_target_mean                                 103
# ItemShouID_target_mean                               86
# AuctionID_target_mean                               238
# ##################
#
#
# ##################
#                                              importance
# SaishuppinKaisuu                                    248
# SankouKakaku                                         69
# watch_AuctionID_cnt                                 145
# watch_BrandID_cnt                                   313
# watch_ItemShouID_cnt                                 71
# watch_ShouhinID_cnt                                 147
# watch_KaiinID_AuctionID_cnt_x                       100
# watch_KaiinID_BrandID_cnt                           316
# watch_KaiinID_ItemShouID_cnt                        180
# watch_KaiinID_ShouhinID_cnt                         119
# bid_AuctionID_cnt                                    59
# bid_BrandID_cnt                                     308
# bid_ItemShouID_cnt                                   56
# bid_ShouhinID_cnt                                    20
# bid_KaiinID_AuctionID_cnt                             0
# bid_KaiinID_BrandID_cnt                             133
# bid_KaiinID_ItemShouID_cnt                           97
# bid_KaiinID_ShouhinID_cnt                             9
# watch_KaiinID_AuctionID_cnt_y                        80
# watch_KaiinID_SaishuppinKaisuu_mean                  83
# watch_KaiinID_SaishuppinKaisuu_sum                  160
# watch_KaiinID_SankouKakaku_mean                     146
# watch_KaiinID_SankouKakaku_sum                      122
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         279
# watch_KaiinID_rate_mean_to_SankouKakaku              81
# Auction_elapsed_days                                332
# KaiinID_watch_elapsed_day_min                        76
# AuctionID_watch_elapsed_day_min                     507
# watch_BrandID_KaiinID_rate                          328
# watch_ItemShouID_KaiinID_rate                       243
# BrandID_SankouKakaku                                 98
# SankouKakaku_rate_to_BrandID                        170
# ItemShouID_SankouKakaku                              92
# SankouKakaku_rate_to_ItemShouID                      64
# watch_interval                                       78
# bid_interval                                        150
# left_day_interval_rate                               79
# left_day_watch_interval_rate                         57
# left_day_bid_interval_rate                          145
# BrandID_target_mean                                  87
# ItemShouID_target_mean                              146
# AuctionID_target_mean                               199
# ##################
# ##################
#                                              importance
# SaishuppinKaisuu                                    281
# SankouKakaku                                         65
# watch_AuctionID_cnt                                 163
# watch_BrandID_cnt                                   203
# watch_ItemShouID_cnt                                 28
# watch_ShouhinID_cnt                                 167
# watch_KaiinID_AuctionID_cnt_x                       114
# watch_KaiinID_BrandID_cnt                           251
# watch_KaiinID_ItemShouID_cnt                        161
# watch_KaiinID_ShouhinID_cnt                         110
# bid_AuctionID_cnt                                    69
# bid_BrandID_cnt                                     330
# bid_ItemShouID_cnt                                   81
# bid_ShouhinID_cnt                                    43
# bid_KaiinID_AuctionID_cnt                             0
# bid_KaiinID_BrandID_cnt                             168
# bid_KaiinID_ItemShouID_cnt                          119
# bid_KaiinID_ShouhinID_cnt                            52
# watch_KaiinID_AuctionID_cnt_y                        95
# watch_KaiinID_SaishuppinKaisuu_mean                  72
# watch_KaiinID_SaishuppinKaisuu_sum                  121
# watch_KaiinID_SankouKakaku_mean                     109
# watch_KaiinID_SankouKakaku_sum                       98
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         313
# watch_KaiinID_rate_mean_to_SankouKakaku             111
# Auction_elapsed_days                                455
# KaiinID_watch_elapsed_day_min                        94
# AuctionID_watch_elapsed_day_min                     483
# watch_BrandID_KaiinID_rate                          296
# watch_ItemShouID_KaiinID_rate                       220
# BrandID_SankouKakaku                                148
# SankouKakaku_rate_to_BrandID                         98
# ItemShouID_SankouKakaku                             113
# SankouKakaku_rate_to_ItemShouID                      92
# watch_interval                                       53
# bid_interval                                        114
# left_day_interval_rate                              100
# left_day_watch_interval_rate                         84
# left_day_bid_interval_rate                           82
# BrandID_target_mean                                 109
# ItemShouID_target_mean                              102
# AuctionID_target_mean                               261
# ##################
#
#
# ##################
#                                              importance
# SaishuppinKaisuu                                    252
# SankouKakaku                                         43
# watch_AuctionID_cnt                                 160
# watch_BrandID_cnt                                   282
# watch_ItemShouID_cnt                                 48
# watch_ShouhinID_cnt                                 161
# watch_KaiinID_AuctionID_cnt_x                       112
# watch_KaiinID_BrandID_cnt                           255
# watch_KaiinID_ItemShouID_cnt                        138
# watch_KaiinID_ShouhinID_cnt                         109
# bid_AuctionID_cnt                                    75
# bid_BrandID_cnt                                     234
# bid_ItemShouID_cnt                                  113
# bid_ShouhinID_cnt                                    36
# bid_KaiinID_AuctionID_cnt                             0
# bid_KaiinID_BrandID_cnt                             195
# bid_KaiinID_ItemShouID_cnt                          106
# bid_KaiinID_ShouhinID_cnt                            10
# watch_KaiinID_AuctionID_cnt_y                        54
# watch_KaiinID_SaishuppinKaisuu_mean                  81
# watch_KaiinID_SaishuppinKaisuu_sum                  132
# watch_KaiinID_SankouKakaku_mean                     126
# watch_KaiinID_SankouKakaku_sum                      123
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         320
# watch_KaiinID_rate_mean_to_SankouKakaku             137
# Auction_elapsed_days                                396
# KaiinID_watch_elapsed_day_min                        97
# AuctionID_watch_elapsed_day_min                     520
# watch_BrandID_KaiinID_rate                          281
# watch_ItemShouID_KaiinID_rate                       247
# BrandID_SankouKakaku                                141
# SankouKakaku_rate_to_BrandID                        159
# ItemShouID_SankouKakaku                              95
# SankouKakaku_rate_to_ItemShouID                      74
# watch_interval                                       72
# bid_interval                                        143
# left_day_interval_rate                               86
# left_day_watch_interval_rate                         54
# left_day_bid_interval_rate                          102
# BrandID_target_mean                                 104
# ItemShouID_target_mean                              100
# AuctionID_target_mean                               231
# ##################
# CPU times: user 1h 21min 18s, sys: 3min 8s, total: 1h 24min 27s
# Wall time: 17min 17s

# %%
 ensemble_buf["private"]["lgb_rank"].shape
# Out:
# (7714125,)

# %%
sub_private_dataset.set_pred(
    ensemble_buf["private"]["lgb_rank"]
    + 5 *(ensemble_buf["private"]["lgb_bin"] + ensemble_buf["private"]["rfc_bin"])
)

sub_business_dataset.set_pred(
    ensemble_buf["business"]["lgb_rank"]
    + 5 * (ensemble_buf["business"]["lgb_bin"] + ensemble_buf["business"]["rfc_bin"])
)

# %%
pred = (
    pd.concat([sub_private_dataset.data[["KaiinID", "AuctionID", "pred"]], sub_business_dataset.data[["KaiinID", "AuctionID", "pred"]]])
    .rename(columns={"pred": "score"})
)
sub = be.adjust_sub_form(sub_users, pred, drop=True)
sub.to_csv(SUB_DIR + datetime.datetime.now().strftime("%Y%m%d%H%M") + "_submit.csv", index=False)
sub.head()
# Out:
#       KaiinID  AuctionID
# 865        24     910664
# 1559       24    4084555
# 77         24      24763
# 944        24    1049414
# 610        24     426583

# %%
# 手元のデータセットでndcg計算
y_true = be.extract_target_actions(watch, bid, dset_to_period["valid_for_sub"])
sub = be.adjust_sub_form(y_true[["KaiinID"]].drop_duplicates(),
                      pd.concat([vs_private_dataset.data[["KaiinID", "AuctionID", "pred"]], vs_business_dataset.data[["KaiinID", "AuctionID", "pred"]]])
                      .rename(columns={"pred":"score"}), drop=True
)
ndcg_score = be.calc_ndcg(y_true, sub)
print("ndcg_score : ", ndcg_score)

# %%
# %%time

# datasets_conf = [
#     {"in_train_dataset": vs_private_dataset, "sub_dataset": sub_private_dataset,
#     "sample_posi": 4, "sample_nega": 400},
#     {"in_train_dataset": vs_business_dataset, "sub_dataset": sub_business_dataset,
#     "sample_posi": 40, "sample_nega": 600}
# ]

# params = {
#     'objective': 'lambdarank',
#     'metric': 'ndcg',
#     "ndcg_at": 20,
#     "nround": 500,
#     "learning_rate": 0.01,
#     "max_depth": 6,
#     "num_leaves": 127
# }

# for dataset_conf in datasets_conf:

#     in_train_dataset = dataset_conf["in_train_dataset"]
#     sub_dataset = dataset_conf["sub_dataset"]

#     seed_buf = {}
#     for seed in range(5):
#         # train test split
#         train_dataset, test_dataset =DataSet.train_test_split(in_train_dataset)
#         sampled_train = DataSet(
#             pd.concat([
#                 train_dataset.data.query("(watch_actioned == 1) | (bid_actioned == 1)").sample(frac=1)
#                 .groupby("KaiinID").head(dataset_conf["sample_posi"]),
#                 train_dataset.data.query("(watch_actioned != 1) & (bid_actioned != 1)").sample(frac=1)
#                 .groupby("KaiinID").head(dataset_conf["sample_nega"]),
#             ]),
#             drop_cols=train_dataset.drop_cols, target_col=train_dataset.target_col
#         )
#         # target encoding
#         cat_cols = ["BrandID", "ItemShouID", "AuctionID"]
#         for cat_col in cat_cols:
#             sampled_train.add_target_encode(cat_col=cat_col)
#             target_encode_for_test(train_dataset=train_dataset, test_dataset=test_dataset, cat_col=cat_col)    

#         params["random_state"] = seed
#         lgb_rank = be.LgbLambdaLank(params=params)
#         lgb_rank.train(train_dataset=sampled_train, valid_dataset=test_dataset, desc=True)

#         for cat_col in cat_cols:
#             be.target_encode_for_test(
#                 train_dataset=in_train_dataset, test_dataset=sub_dataset, cat_col=cat_col
#             )
        
#         seed_buf[seed] = lgb_rank.predict(sub_dataset)
    
#     sub_dataset.set_pred(reduce(lambda a,b: a+b, [v for v in seed_buf.values()]))

# %%
# pred = (
#     pd.concat([sub_private_dataset.data[["KaiinID", "AuctionID", "pred"]], sub_business_dataset.data[["KaiinID", "AuctionID", "pred"]]])
#     .rename(columns={"pred": "score"})
# )
# sub = be.adjust_sub_form(sub_users, pred, drop=True)
# sub.to_csv(SUB_DIR + datetime.datetime.now().strftime("%Y%m%d%H%M") + "_submit.csv", index=False)
# sub.head()
# Out:
#       KaiinID  AuctionID
# 610        24     426583
# 865        24     910664
# 491        24     255022
# 1559       24    4084555
# 590        24     397019

# %%
# %%time

datasets_conf = [
    {"in_train_dataset": vs_private_dataset, "sub_dataset": sub_private_dataset,
    "sample_posi": 4, "sample_nega": 400},
    {"in_train_dataset": vs_business_dataset, "sub_dataset": sub_business_dataset,
    "sample_posi": 40, "sample_nega": 600}
]

for dataset_conf in datasets_conf:
    
    print(dataset_conf)

    in_train_dataset = dataset_conf["in_train_dataset"]
    sub_dataset = dataset_conf["sub_dataset"]
    
    # train test split
    train_dataset, test_dataset =DataSet.train_test_split(in_train_dataset)
    sampled_train = DataSet(
        pd.concat([
            train_dataset.data.query("(watch_actioned == 1) | (bid_actioned == 1)").sample(frac=1)
            .groupby("KaiinID").head(dataset_conf["sample_posi"]),
            train_dataset.data.query("(watch_actioned != 1) & (bid_actioned != 1)").sample(frac=1)
            .groupby("KaiinID").head(dataset_conf["sample_nega"]),
        ]),
        drop_cols=train_dataset.drop_cols, target_col=train_dataset.target_col
    )
    # target encoding
    cat_cols = ["BrandID", "ItemShouID", "AuctionID"]
    for cat_col in cat_cols:
        sampled_train.add_target_encode(cat_col=cat_col)
        target_encode_for_test(train_dataset=train_dataset, test_dataset=test_dataset, cat_col=cat_col)    

#     lgb_rank = be.LgbLambdaLank()
#     lgb_rank.train(train_dataset=sampled_train, valid_dataset=test_dataset, desc=True)

    print(datetime.datetime.now())

    lgb_bin = be.LgbBinaryClassifier()
    lgb_bin.train(train_dataset=sampled_train)
    print('lgb_bin_auc = ', roc_auc_score(y_true=test_dataset.get_target(), y_score=lgb_bin.predict(dataset=test_dataset)))
    
    print(datetime.datetime.now())    
    
    log_bin = LogBinaryClassifier()
    log_bin.train(train_dataset=sampled_train)
    print('log_bin_auc = ', roc_auc_score(y_true=test_dataset.get_target(), y_score=log_bin.predict(dataset=test_dataset)))
    
    print(datetime.datetime.now())
    
    rfc_bin = RfcBinaryClassifier()
    rfc_bin.train(train_dataset=sampled_train)
    print('rfc_bin_auc = ', roc_auc_score(y_true=test_dataset.get_target(), y_score=rfc_bin.predict(dataset=test_dataset)))

#     impo = lgb_rank.get_model_info(sampled_train)
#     print(impo.sort_values("importance", ascending=False).head(10))
#     print(impo.sort_values("importance", ascending=False).tail(10))
    
#     for cat_col in cat_cols:
#         be.target_encode_for_test(
#             train_dataset=in_train_dataset, test_dataset=sub_dataset, cat_col=cat_col
#         )
#     sub_dataset.set_pred(lgb_rank.predict(sub_dataset))
# Out:
# {'in_train_dataset': <__main__.DataSet object at 0x138b68690>, 'sub_dataset': <brandear_est.dataset.DataSet object at 0x14cc23750>, 'sample_posi': 6, 'sample_nega': 400}
# 2020-02-23 13:47:17.468316
# lgb_bin_auc =  0.8961084580184953
# 2020-02-23 13:47:42.716017
# log_bin_auc =  0.5900284945966483
# 2020-02-23 13:48:28.763870
# rfc_bin_auc =  0.8076873495547944
# {'in_train_dataset': <__main__.DataSet object at 0x14a529c90>, 'sub_dataset': <brandear_est.dataset.DataSet object at 0x14ba18e90>, 'sample_posi': 20, 'sample_nega': 200}
# 2020-02-23 13:54:43.929730
# lgb_bin_auc =  0.9024449180943876
# 2020-02-23 13:54:49.086023
# log_bin_auc =  0.4976404174592071
# 2020-02-23 13:54:55.295135
# rfc_bin_auc =  0.9016588816449899
# CPU times: user 51min 23s, sys: 1min 1s, total: 52min 25s
# Wall time: 8min 54s

# %%
pred = (
    pd.concat([sub_private_dataset.data[["KaiinID", "AuctionID", "pred"]], sub_business_dataset.data[["KaiinID", "AuctionID", "pred"]]])
    .rename(columns={"pred": "score"})
)
sub = be.adjust_sub_form(sub_users, pred, drop=True)
sub.to_csv(SUB_DIR + datetime.datetime.now().strftime("%Y%m%d%H%M") + "_submit.csv", index=False)
sub.head()
# Out:
#       KaiinID  AuctionID
# 770        24    2046288
# 1444       24    3720443
# 1309       24    3405601
# 473        24    1200326
# 142        24     333844

# %%
# # 手元のデータセットでndcg計算
# y_true = be.extract_target_actions(watch, bid, dset_to_period["valid_for_sub"])
# sub = be.adjust_sub_form(y_true[["KaiinID"]].drop_duplicates(),
#                       pd.concat([vs_private_dataset.data[["KaiinID", "AuctionID", "pred"]], vs_business_dataset.data[["KaiinID", "AuctionID", "pred"]]])
#                       .rename(columns={"pred":"score"}), drop=True
# )
# ndcg_score = be.calc_ndcg(y_true, sub)
# print("ndcg_score : ", ndcg_score)
# Out:
# ndcg_score :  0.061767156609773444

# %%
tmp_1 = pd.read_pickle(IMD_EST_WEEKLY_DIR + f"/valid_for_sub_1600.pkl")

# %%
tmp_1.query("watch_actioned == 1").describe()
# Out:
#              KaiinID     AuctionID  SaishuppinKaisuu  SankouKakaku  \
# count    5781.000000  5.781000e+03       5781.000000  5.781000e+03
# mean   138209.588307  2.020029e+06        122.162775  3.321863e+04
# std     79567.123196  1.195205e+06        163.086478  8.476083e+04
# min        22.000000  5.190000e+02          0.000000  1.000000e+03
# 25%     69426.000000  9.696310e+05          0.000000  2.500000e+03
# 50%    135756.000000  2.020680e+06          0.000000  5.500000e+03
# 75%    205960.000000  3.037687e+06        339.000000  2.800000e+04
# max    277891.000000  4.108619e+06        370.000000  1.467000e+06
#
#        1m_watch_AuctionID_cnt  1m_watch_ShouhinID_cnt  \
# count             5781.000000             5781.000000
# mean                 2.285072                2.508736
# std                  3.692511                4.308734
# min                  0.000000                0.000000
# 25%                  0.000000                0.000000
# 50%                  1.000000                1.000000
# 75%                  3.000000                3.000000
# max                 36.000000               54.000000
#
#        1m_watch_ItemShouID_cnt  elapsed_days  watch_elapsed_days  \
# count              5781.000000   5781.000000         5781.000000
# mean              12518.893963     31.921294           21.702647
# std                9248.049049     39.584475           36.230977
# min                 230.000000      0.000000            0.000000
# 25%                5194.000000      6.000000            0.000000
# 50%                9276.000000     17.000000            5.000000
# 75%               21177.000000     45.000000           30.000000
# max               28330.000000    388.000000          331.000000
#
#        watch_actioned  bid_actioned   KaiinID_cnt  KaiinID_AuctionID_cnt  \
# count          5781.0   5781.000000   5781.000000            5781.000000
# mean              1.0      0.055008    913.843107               0.124200
# std               0.0      0.228015   1503.947890               0.424758
# min               1.0      0.000000      0.000000               0.000000
# 25%               1.0      0.000000    114.000000               0.000000
# 50%               1.0      0.000000    413.000000               0.000000
# 75%               1.0      0.000000   1048.000000               0.000000
# max               1.0      1.000000  19728.000000               9.000000
#
#        KaiinID_ShouhinID_cnt  BrandID_KaiinID_rate  ItemShouID_KaiinID_rate  \
# count             5781.00000           5781.000000              5781.000000
# mean                 0.17004              0.265569                 0.218972
# std                  0.51008              0.299500                 0.214414
# min                  0.00000              0.000000                 0.000000
# 25%                  0.00000              0.046638                 0.066562
# 50%                  0.00000              0.129630                 0.148810
# 75%                  0.00000              0.387898                 0.300000
# max                  9.00000              1.000000                 1.000000
#
#               pred         rank
# count  5781.000000  5781.000000
# mean      0.192053   519.505276
# std       0.116140   460.559756
# min       0.010883     0.000000
# 25%       0.103287   121.000000
# 50%       0.157708   373.000000
# 75%       0.263722   861.000000
# max       0.606660  1600.000000

# %%
tmp_1.query("watch_actioned != 1").describe()
# Out:
#             KaiinID     AuctionID  SaishuppinKaisuu  SankouKakaku  \
# count  1.015096e+07  1.015096e+07      1.015096e+07  1.015096e+07
# mean   1.380691e+05  2.052264e+06      8.208515e+01  3.098772e+04
# std    7.922971e+04  1.190232e+06      1.453422e+02  7.766975e+04
# min    2.200000e+01  6.000000e+01      0.000000e+00  2.000000e+01
# 25%    6.937100e+04  1.010363e+06      0.000000e+00  2.134000e+03
# 50%    1.388580e+05  2.059128e+06      0.000000e+00  6.000000e+03
# 75%    2.046370e+05  3.075842e+06      0.000000e+00  3.000000e+04
# max    2.778910e+05  4.109557e+06      3.700000e+02  2.925000e+06
#
#        1m_watch_AuctionID_cnt  1m_watch_ShouhinID_cnt  \
# count            1.015096e+07            1.015096e+07
# mean             2.540751e+00            2.848138e+00
# std              3.898006e+00            4.351864e+00
# min              0.000000e+00            0.000000e+00
# 25%              0.000000e+00            0.000000e+00
# 50%              1.000000e+00            1.000000e+00
# 75%              3.000000e+00            4.000000e+00
# max              5.100000e+01            5.400000e+01
#
#        1m_watch_ItemShouID_cnt  elapsed_days  watch_elapsed_days  \
# count             1.015096e+07  1.015096e+07        1.015096e+07
# mean              1.336008e+04  3.257321e+01        2.159112e+01
# std               9.873415e+03  4.275357e+01        3.762470e+01
# min               3.200000e+01  0.000000e+00        0.000000e+00
# 25%               5.164000e+03  6.000000e+00        0.000000e+00
# 50%               9.276000e+03  1.400000e+01        4.000000e+00
# 75%               2.534500e+04  4.500000e+01        2.900000e+01
# max               2.833000e+04  5.330000e+02        3.660000e+02
#
#        watch_actioned  bid_actioned   KaiinID_cnt  KaiinID_AuctionID_cnt  \
# count      10150963.0  1.015096e+07  1.015096e+07           1.015096e+07
# mean              0.0  1.105314e-04  3.915700e+02           1.575062e-02
# std               0.0  1.051281e-02  1.049791e+03           1.299115e-01
# min               0.0  0.000000e+00  0.000000e+00           0.000000e+00
# 25%               0.0  0.000000e+00  1.400000e+01           0.000000e+00
# 50%               0.0  0.000000e+00  1.080000e+02           0.000000e+00
# 75%               0.0  0.000000e+00  3.860000e+02           0.000000e+00
# max               0.0  1.000000e+00  2.437100e+04           1.200000e+01
#
#        KaiinID_ShouhinID_cnt  BrandID_KaiinID_rate  ItemShouID_KaiinID_rate  \
# count           1.015096e+07          1.015096e+07             1.015096e+07
# mean            1.887200e-02          1.541944e-01             1.700955e-01
# std             1.478592e-01          2.436185e-01             2.207432e-01
# min             0.000000e+00          0.000000e+00             0.000000e+00
# 25%             0.000000e+00          3.627883e-03             2.439024e-02
# 50%             0.000000e+00          4.615385e-02             9.090909e-02
# 75%             0.000000e+00          1.764706e-01             2.213247e-01
# max             1.300000e+01          1.000000e+00             1.000000e+00
#
#                pred          rank
# count  1.015096e+07  1.015096e+07
# mean   1.053756e-01  8.001597e+02
# std    8.781854e-02  4.621213e+02
# min    7.823493e-03  0.000000e+00
# 25%    3.748928e-02  4.000000e+02
# 50%    8.510337e-02  8.000000e+02
# 75%    1.387162e-01  1.200000e+03
# max    7.586941e-01  1.600000e+03

# %%
# 手元のデータで最善の予測をした際の結果
tmp_1 = pd.read_pickle(IMD_EST_WEEKLY_DIR + f"/valid_for_sub_1600.pkl")
tmp_2 = pd.read_pickle(IMD_EST_WEEKLY_DIR + f"/watch_valid_for_sub_1600.pkl")

dset_type = "valid_for_sub"

# データの時系列整理
watch_arranged, bid_arranged, bid_success_arranged, auction_arranged = (
    arrange_inputs(watch=watch, bid=bid, bid_success=bid_success, auction=auction_mst, period=dset_to_period[dset_type])
)

y_true = extract_target_actions(watch=watch, bid=bid, period=dset_to_period[dset_type])    

tmp_sim = extract_similar_aucs(
    target_users=target_actions[["KaiinID"]].drop_duplicates(),
    auction=auction_arranged,
    actions=pd.concat([watch_arranged, bid_arranged])[["KaiinID", "ShouhinID"]]
)[["AuctionID", "KaiinID"]].drop_duplicates()

cheat_pred = be.get_cheat_pred(
#     pd.concat([tmp_1[["KaiinID", "AuctionID"]].merge(tmp_2[["KaiinID", "AuctionID"]], on=["KaiinID", "AuctionID"]), tmp_sim]).drop_duplicates(),
    pd.concat([tmp_1[["KaiinID", "AuctionID"]], tmp_sim]).drop_duplicates(),    
    y_true
)
cheat_sub = be.adjust_sub_form(y_true[["KaiinID"]].drop_duplicates(), cheat_pred, drop=True)
cheat_dcgs = calc_ndcg(y_true, cheat_sub)
print(cheat_dcgs.mean())
cheat_dcgs = cheat_dcgs.reset_index()
# Out:
# /Users/nobuyuki.ishida/.pyenv/versions/3.7.5/lib/python3.7/site-packages/ipykernel_launcher.py:17: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# /Users/nobuyuki.ishida/.pyenv/versions/3.7.5/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# 0.16342004150309675

# %%
# 各データのdcg確認
y_true = be.extract_target_actions(watch, bid, dset_to_period["valid_for_sub"])
sub = be.adjust_sub_form(y_true[["KaiinID"]].drop_duplicates(),
                      pd.concat([vs_private_dataset.data[["KaiinID", "AuctionID", "pred"]], vs_business_dataset.data[["KaiinID", "AuctionID", "pred"]]])
                      .rename(columns={"pred":"score"}), drop=True
)
dcgs = calc_ndcg(y_true, sub)
dcgs = dcgs.reset_index()

# %%
dcg_infos = (
    dcgs.merge(watch_cnt, on="KaiinID", how="left")
    .merge(bid_cnt, on="KaiinID", how="left")
    .merge(y_true.drop("AuctionID", axis=1).groupby("KaiinID", as_index=False).sum(), on="KaiinID", how="left")
    .merge(cheat_dcgs.rename(columns={"score": "cheat_score"}), on="KaiinID", how="left")
    .fillna(0)
)
print(dcg_infos.corr())
print(dcg_infos.query("score == 0").describe())
print(dcg_infos.query("score != 0").describe())
print(dcg_infos.query("(watch_cnt < 1000) & (bid_cnt < 50)").describe())
print(dcg_infos.query("(watch_cnt >= 1000) | (bid_cnt >= 50)").describe())
print((dcg_infos["cheat_score"] == 0).sum())
# Out:
#                  KaiinID     score  watch_cnt   bid_cnt  watch_actioned  \
# KaiinID         1.000000  0.004205  -0.012328 -0.003893       -0.016975
# score           0.004205  1.000000   0.025938  0.031368        0.020287
# watch_cnt      -0.012328  0.025938   1.000000  0.509239        0.622164
# bid_cnt        -0.003893  0.031368   0.509239  1.000000        0.325908
# watch_actioned -0.016975  0.020287   0.622164  0.325908        1.000000
# bid_actioned   -0.017098  0.091771   0.248743  0.616189        0.386692
# cheat_score    -0.001473  0.450758   0.194837  0.115459        0.182354
#
#                 bid_actioned  cheat_score
# KaiinID            -0.017098    -0.001473
# score               0.091771     0.450758
# watch_cnt           0.248743     0.194837
# bid_cnt             0.616189     0.115459
# watch_actioned      0.386692     0.182354
# bid_actioned        1.000000     0.108280
# cheat_score         0.108280     1.000000
#              KaiinID   score     watch_cnt      bid_cnt  watch_actioned  \
# count    4731.000000  4731.0   4731.000000  4731.000000     4731.000000
# mean   138472.024308     0.0    290.765800    38.883746        9.422532
# std     79628.441814     0.0    694.447677   162.788668       19.260726
# min        22.000000     0.0      0.000000     0.000000        0.000000
# 25%     68835.500000     0.0      7.000000     0.000000        1.000000
# 50%    139288.000000     0.0     82.000000     6.000000        3.000000
# 75%    206266.000000     0.0    310.000000    30.000000       10.000000
# max    277891.000000     0.0  19728.000000  5585.000000      345.000000
#
#        bid_actioned  cheat_score
# count   4731.000000  4731.000000
# mean       0.887973     0.272148
# std        3.879872     0.345243
# min        0.000000     0.000000
# 25%        0.000000     0.000000
# 50%        0.000000     0.000000
# 75%        1.000000     0.501501
# max      123.000000     1.000000
#              KaiinID        score     watch_cnt      bid_cnt  watch_actioned  \
# count    1613.000000  1613.000000   1613.000000  1613.000000     1613.000000
# mean   136887.568506     0.235939    688.402356   100.125852       25.103534
# std     78086.592008     0.210386   1675.501390   341.092288       55.478193
# min       173.000000     0.011146      0.000000     0.000000        0.000000
# 25%     71485.000000     0.088878     58.000000     4.000000        3.000000
# 50%    137209.000000     0.169277    203.000000    19.000000        9.000000
# 75%    199453.000000     0.307422    627.000000    65.000000       24.000000
# max    277848.000000     1.000000  24371.000000  5290.000000      820.000000
#
#        bid_actioned  cheat_score
# count   1613.000000  1613.000000
# mean       3.647861     0.700574
# std        9.759261     0.229296
# min        0.000000     0.096452
# 25%        0.000000     0.540012
# 50%        1.000000     0.714350
# 75%        4.000000     0.901359
# max      163.000000     1.000000
#              KaiinID        score    watch_cnt      bid_cnt  watch_actioned  \
# count    4906.000000  4906.000000  4906.000000  4906.000000     4906.000000
# mean   138287.207705     0.058005   132.263759     9.505911        8.164492
# std     79345.025250     0.153721   184.051822    12.235477       19.614014
# min        22.000000     0.000000     0.000000     0.000000        0.000000
# 25%     69279.750000     0.000000     6.000000     0.000000        1.000000
# 50%    138734.000000     0.000000    55.000000     4.000000        3.000000
# 75%    205016.250000     0.000000   181.000000    15.000000        8.000000
# max    277848.000000     1.000000   993.000000    49.000000      820.000000
#
#        bid_actioned  cheat_score
# count   4906.000000  4906.000000
# mean       0.756828     0.348720
# std        2.388253     0.376714
# min        0.000000     0.000000
# 25%        0.000000     0.000000
# 50%        0.000000     0.242076
# 75%        1.000000     0.645367
# max       86.000000     1.000000
#              KaiinID        score     watch_cnt      bid_cnt  watch_actioned  \
# count    1438.000000  1438.000000   1438.000000  1438.000000     1438.000000
# mean   137325.280946     0.066757   1277.552156   207.806676       31.303894
# std     78886.492811     0.124631   1933.449880   435.818150       56.143346
# min       237.000000     0.000000      0.000000     0.000000        0.000000
# 25%     69683.500000     0.000000    385.000000    62.000000        5.000000
# 50%    138998.000000     0.000000    731.000000    93.000000       14.000000
# 75%    202744.750000     0.089617   1404.000000   176.000000       36.000000
# max    277891.000000     1.000000  24371.000000  5585.000000      780.000000
#
#        bid_actioned  cheat_score
# count   1438.000000  1438.000000
# mean       4.431154     0.491473
# std       11.526095     0.323704
# min        0.000000     0.000000
# 25%        0.000000     0.231657
# 50%        1.000000     0.516742
# 75%        4.000000     0.758357
# max      163.000000     1.000000
# 2488

# %%
dcg_infos = (
    dcgs.merge(watch_cnt, on="KaiinID", how="left")
    .merge(bid_cnt, on="KaiinID", how="left")
    .merge(y_true.drop("AuctionID", axis=1).groupby("KaiinID", as_index=False).sum(), on="KaiinID", how="left")
    .merge(cheat_dcgs.rename(columns={"score": "cheat_score"}), on="KaiinID", how="left")
    .fillna(0)
)
print(dcg_infos.corr())
print(dcg_infos.query("score == 0").describe())
print(dcg_infos.query("score != 0").describe())
print(dcg_infos.query("(watch_cnt < 1000) & (bid_cnt < 50)").describe())
print(dcg_infos.query("(watch_cnt >= 1000) | (bid_cnt >= 50)").describe())
print((dcg_infos["cheat_score"] == 0).sum())
# Out:
#                  KaiinID     score  watch_cnt   bid_cnt  watch_actioned  \
# KaiinID         1.000000  0.003172  -0.012328 -0.003893       -0.016975
# score           0.003172  1.000000   0.036683  0.032339        0.033200
# watch_cnt      -0.012328  0.036683   1.000000  0.509239        0.622164
# bid_cnt        -0.003893  0.032339   0.509239  1.000000        0.325908
# watch_actioned -0.016975  0.033200   0.622164  0.325908        1.000000
# bid_actioned   -0.017098  0.094064   0.248743  0.616189        0.386692
# cheat_score    -0.000572  0.509597   0.191796  0.116161        0.183219
#
#                 bid_actioned  cheat_score
# KaiinID            -0.017098    -0.000572
# score               0.094064     0.509597
# watch_cnt           0.248743     0.191796
# bid_cnt             0.616189     0.116161
# watch_actioned      0.386692     0.183219
# bid_actioned        1.000000     0.119938
# cheat_score         0.119938     1.000000
#              KaiinID   score     watch_cnt      bid_cnt  watch_actioned  \
# count    4642.000000  4642.0   4642.000000  4642.000000     4642.000000
# mean   138139.897243     0.0    276.767773    36.056441        9.014003
# std     79509.106175     0.0    650.031213   153.983753       17.800409
# min        22.000000     0.0      0.000000     0.000000        0.000000
# 25%     68537.750000     0.0      7.000000     0.000000        1.000000
# 50%    139113.000000     0.0     79.000000     6.000000        3.000000
# 75%    205822.250000     0.0    301.000000    28.000000        9.000000
# max    277891.000000     0.0  19728.000000  5585.000000      345.000000
#
#        bid_actioned  cheat_score
# count   4642.000000  4642.000000
# mean       0.836062     0.215428
# std        3.722149     0.318493
# min        0.000000     0.000000
# 25%        0.000000     0.000000
# 50%        0.000000     0.000000
# 75%        1.000000     0.390380
# max      123.000000     1.000000
#              KaiinID        score     watch_cnt      bid_cnt  watch_actioned  \
# count    1702.000000  1702.000000   1702.000000  1702.000000     1702.000000
# mean   137876.258519     0.249090    705.787309   104.634548       25.397767
# std     78509.731769     0.217998   1680.964305   344.183206       55.328327
# min       173.000000     0.011146      0.000000     0.000000        0.000000
# 25%     71882.500000     0.093389     59.000000     4.000000        3.000000
# 50%    138168.000000     0.180520    210.000000    20.000000        9.000000
# 75%    201383.000000     0.337611    639.500000    71.000000       25.000000
# max    277848.000000     1.000000  24371.000000  5290.000000      820.000000
#
#        bid_actioned  cheat_score
# count   1702.000000  1702.000000
# mean       3.645123     0.671802
# std        9.691650     0.237900
# min        0.000000     0.056335
# 25%        0.000000     0.492041
# 50%        1.000000     0.672023
# 75%        4.000000     0.868686
# max      163.000000     1.000000
#              KaiinID        score    watch_cnt      bid_cnt  watch_actioned  \
# count    4906.000000  4906.000000  4906.000000  4906.000000     4906.000000
# mean   138287.207705     0.063854   132.263759     9.505911        8.164492
# std     79345.025250     0.163820   184.051822    12.235477       19.614014
# min        22.000000     0.000000     0.000000     0.000000        0.000000
# 25%     69279.750000     0.000000     6.000000     0.000000        1.000000
# 50%    138734.000000     0.000000    55.000000     4.000000        3.000000
# 75%    205016.250000     0.000000   181.000000    15.000000        8.000000
# max    277848.000000     1.000000   993.000000    49.000000      820.000000
#
#        bid_actioned  cheat_score
# count   4906.000000  4906.000000
# mean       0.756828     0.307252
# std        2.388253     0.365249
# min        0.000000     0.000000
# 25%        0.000000     0.000000
# 50%        0.000000     0.000000
# 75%        1.000000     0.613147
# max       86.000000     1.000000
#              KaiinID        score     watch_cnt      bid_cnt  watch_actioned  \
# count    1438.000000  1438.000000   1438.000000  1438.000000     1438.000000
# mean   137325.280946     0.076970   1277.552156   207.806676       31.303894
# std     78886.492811     0.135234   1933.449880   435.818150       56.143346
# min       237.000000     0.000000      0.000000     0.000000        0.000000
# 25%     69683.500000     0.000000    385.000000    62.000000        5.000000
# 50%    138998.000000     0.000000    731.000000    93.000000       14.000000
# 75%    202744.750000     0.105602   1404.000000   176.000000       36.000000
# max    277891.000000     1.000000  24371.000000  5585.000000      780.000000
#
#        bid_actioned  cheat_score
# count   1438.000000  1438.000000
# mean       4.431154     0.442313
# std       11.526095     0.324998
# min        0.000000     0.000000
# 25%        0.000000     0.142040
# 50%        1.000000     0.469279
# 75%        4.000000     0.712806
# max      163.000000     1.000000
# 2794

# %%
def stack_target_actions(target_actions):
    watch_target = target_actions.query("(watch_actioned == 1)")[["KaiinID", "AuctionID"]]
    bid_target = target_actions.query("(bid_actioned == 1)")[["KaiinID", "AuctionID"]]
    watch_target["score"] = 1
    bid_target["score"] = 2
    stacked_target_actions = pd.concat([watch_target, bid_target], sort=False)
    return stacked_target_actions

def dcg_at_k(r, k):
    r = np.asfarray(r)[:k]
    return np.sum((2 ** r - 1) / np.log2(np.arange(2, r.size + 2)))


def ndcg_at_k(r, k):
    dcg_max = dcg_at_k(sorted(r, reverse=True), k)
    if not dcg_max:
        return 0.
    return dcg_at_k(r, k) / dcg_max


def calc_ndcg(y_true, y_pred, k=20):
    y_pred_cp = y_pred.copy()

    actione_true = stack_target_actions(y_true)
    actione_true["rank"] = 100

    y_pred_cp['rank'] = y_pred_cp.groupby('KaiinID')['AuctionID'].cumcount()

    scored_pred = (
        y_pred_cp.merge(actione_true[["KaiinID", "AuctionID", "score"]], on=["KaiinID", "AuctionID"],
                        how="left").fillna(0))

    unchoiced_actiones = (
        be.left_anti_join(actione_true, y_pred_cp, ["KaiinID", "AuctionID"], ["KaiinID", "AuctionID"]))

    scored_actiones = (
        pd.concat([scored_pred, unchoiced_actiones], sort=False)
            .sort_values(["KaiinID", "rank"], ascending=["True", "True"]))

    dcgs = scored_actiones.groupby("KaiinID")["score"].apply(lambda s: ndcg_at_k(s.tolist(), k=20))
#     ndcg = dcgs.mean()

    return dcgs

# %%
# ランダムな予測の場合
y_true = extract_target_actions(watch, bid, dset_to_period["valid_for_sub"])
random_pred = watch_vs_dataset.data[["KaiinID", "AuctionID"]].copy()
random_pred["score"] = pd.Series(np.random.random(len(random_pred)), index=random_pred.index)
random_sub = be.adjust_sub_form(y_true[["KaiinID"]].drop_duplicates(), random_pred, drop=True)
ndcg_score = calc_ndcg(y_true, random_sub)
print("ndcg_score : ", ndcg_score.mean())
# Out:
# ndcg_score :  0.012993657402914974

# %%
# %%time
# watch学習

dataset_pairs = [
    [watch_vt_dataset, watch_vs_dataset]
]

sample_flg = True

# 学習の様子可視化
for in_train_dataset, sub_dataset in dataset_pairs:
    
    # train test split
    train_dataset, test_dataset =be.DataSet.train_test_split(in_train_dataset)
    
    lgb_rank = be.LgbLambdaLank()
    
    if sample_flg:
        sampled_train = be.DataSet.under_sampling(train_dataset, rate=100)

        # target encoding
        cat_cols = ["BrandID", "GenreID"]
        for cat_col in cat_cols:
            sampled_train.add_target_encode(cat_col=cat_col)
            be.target_encode_for_test(train_dataset=sampled_train, test_dataset=test_dataset, cat_col=cat_col)    
    
        lgb_rank.train(train_dataset=sampled_train, valid_dataset=test_dataset, desc=True)

    else:
        # target encoding
        cat_cols = ["BrandID", "GenreID"]
        for cat_col in cat_cols:
            train_dataset.add_target_encode(cat_col=cat_col)
            be.target_encode_for_test(train_dataset=train_dataset, test_dataset=test_dataset, cat_col=cat_col)    
        lgb_rank.train(train_dataset=train_dataset, valid_dataset=test_dataset, desc=True)        

    for cat_col in cat_cols:
        be.target_encode_for_test(train_dataset=in_train_dataset, test_dataset=sub_dataset, cat_col=cat_col)        
    sub_dataset.set_pred(lgb_rank.predict(sub_dataset))
# Out:
# [1]	valid_0's ndcg@20: 0.895492
# [2]	valid_0's ndcg@20: 0.899167
# [3]	valid_0's ndcg@20: 0.901706
# [4]	valid_0's ndcg@20: 0.90204
# [5]	valid_0's ndcg@20: 0.902014
# [6]	valid_0's ndcg@20: 0.904161
# [7]	valid_0's ndcg@20: 0.904586
# [8]	valid_0's ndcg@20: 0.904388
# [9]	valid_0's ndcg@20: 0.903982
# [10]	valid_0's ndcg@20: 0.904519
# [11]	valid_0's ndcg@20: 0.904724
# [12]	valid_0's ndcg@20: 0.904628
# [13]	valid_0's ndcg@20: 0.905696
# [14]	valid_0's ndcg@20: 0.906099
# [15]	valid_0's ndcg@20: 0.9062
# [16]	valid_0's ndcg@20: 0.906725
# [17]	valid_0's ndcg@20: 0.906832
# [18]	valid_0's ndcg@20: 0.906856
# [19]	valid_0's ndcg@20: 0.906618
# [20]	valid_0's ndcg@20: 0.906919
# [21]	valid_0's ndcg@20: 0.906747
# [22]	valid_0's ndcg@20: 0.90672
# [23]	valid_0's ndcg@20: 0.906723
# [24]	valid_0's ndcg@20: 0.9068
# [25]	valid_0's ndcg@20: 0.907222
# [26]	valid_0's ndcg@20: 0.907357
# [27]	valid_0's ndcg@20: 0.907309
# [28]	valid_0's ndcg@20: 0.90717
# [29]	valid_0's ndcg@20: 0.907048
# [30]	valid_0's ndcg@20: 0.907188
# [31]	valid_0's ndcg@20: 0.907131
# [32]	valid_0's ndcg@20: 0.907305
# [33]	valid_0's ndcg@20: 0.907171
# [34]	valid_0's ndcg@20: 0.90711
# [35]	valid_0's ndcg@20: 0.907028
# [36]	valid_0's ndcg@20: 0.907126
# [37]	valid_0's ndcg@20: 0.907331
# [38]	valid_0's ndcg@20: 0.907294
# [39]	valid_0's ndcg@20: 0.907533
# [40]	valid_0's ndcg@20: 0.907525
# [41]	valid_0's ndcg@20: 0.907668
# [42]	valid_0's ndcg@20: 0.907689
# [43]	valid_0's ndcg@20: 0.907842
# [44]	valid_0's ndcg@20: 0.907703
# [45]	valid_0's ndcg@20: 0.907449
# [46]	valid_0's ndcg@20: 0.907627
# [47]	valid_0's ndcg@20: 0.907575
# [48]	valid_0's ndcg@20: 0.907417
# [49]	valid_0's ndcg@20: 0.907549
# [50]	valid_0's ndcg@20: 0.907593
# [51]	valid_0's ndcg@20: 0.907763
# [52]	valid_0's ndcg@20: 0.907805
# [53]	valid_0's ndcg@20: 0.907623
# [54]	valid_0's ndcg@20: 0.907566
# [55]	valid_0's ndcg@20: 0.90779
# [56]	valid_0's ndcg@20: 0.907783
# [57]	valid_0's ndcg@20: 0.907704
# [58]	valid_0's ndcg@20: 0.907584
# [59]	valid_0's ndcg@20: 0.907432
# [60]	valid_0's ndcg@20: 0.907429
# [61]	valid_0's ndcg@20: 0.90758
# [62]	valid_0's ndcg@20: 0.907604
# [63]	valid_0's ndcg@20: 0.907398
# [64]	valid_0's ndcg@20: 0.907468
# [65]	valid_0's ndcg@20: 0.907555
# [66]	valid_0's ndcg@20: 0.907429
# [67]	valid_0's ndcg@20: 0.907536
# [68]	valid_0's ndcg@20: 0.90744
# [69]	valid_0's ndcg@20: 0.907598
# [70]	valid_0's ndcg@20: 0.907497
# [71]	valid_0's ndcg@20: 0.907193
# [72]	valid_0's ndcg@20: 0.907218
# [73]	valid_0's ndcg@20: 0.907121
# [74]	valid_0's ndcg@20: 0.907202
# [75]	valid_0's ndcg@20: 0.907413
# [76]	valid_0's ndcg@20: 0.907494
# [77]	valid_0's ndcg@20: 0.907305
# [78]	valid_0's ndcg@20: 0.907575
# [79]	valid_0's ndcg@20: 0.907586
# [80]	valid_0's ndcg@20: 0.907555
# [81]	valid_0's ndcg@20: 0.907728
# [82]	valid_0's ndcg@20: 0.907809
# [83]	valid_0's ndcg@20: 0.907732
# [84]	valid_0's ndcg@20: 0.907603
# [85]	valid_0's ndcg@20: 0.907641
# [86]	valid_0's ndcg@20: 0.90785
# [87]	valid_0's ndcg@20: 0.907697
# [88]	valid_0's ndcg@20: 0.907633
# [89]	valid_0's ndcg@20: 0.907673
# [90]	valid_0's ndcg@20: 0.907671
# [91]	valid_0's ndcg@20: 0.907491
# [92]	valid_0's ndcg@20: 0.907591
# [93]	valid_0's ndcg@20: 0.907534
# [94]	valid_0's ndcg@20: 0.90748
# [95]	valid_0's ndcg@20: 0.907608
# [96]	valid_0's ndcg@20: 0.907592
# [97]	valid_0's ndcg@20: 0.907576
# [98]	valid_0's ndcg@20: 0.907457
# [99]	valid_0's ndcg@20: 0.907391
# [100]	valid_0's ndcg@20: 0.907493
#
#
# ##################
#                                              importance
# SaishuppinKaisuu                                    335
# SankouKakaku                                        266
# watch_AuctionID_cnt                                 144
# watch_BrandID_cnt                                    97
# watch_ItemShouID_cnt                                143
# watch_LineID_cnt                                      0
# watch_ShouhinID_cnt                                  94
# watch_ShouhinShubetsuID_cnt                           0
# watch_KaiinID_AuctionID_cnt_x                       170
# watch_KaiinID_BrandID_cnt                           165
# watch_KaiinID_ItemShouID_cnt                         98
# watch_KaiinID_LineID_cnt                             69
# watch_KaiinID_ShouhinID_cnt                          30
# watch_KaiinID_ShouhinShubetsuID_cnt                  46
# bid_AuctionID_cnt                                   141
# bid_BrandID_cnt                                     156
# bid_ItemShouID_cnt                                   57
# bid_ShouhinID_cnt                                   101
# bid_KaiinID_AuctionID_cnt                             3
# bid_KaiinID_BrandID_cnt                              87
# bid_KaiinID_ItemShouID_cnt                           45
# bid_KaiinID_LineID_cnt                               55
# bid_KaiinID_ShouhinID_cnt                            23
# bid_KaiinID_ShouhinShubetsuID_cnt                   106
# watch_KaiinID_AuctionID_cnt_y                        64
# watch_KaiinID_ConditionID_mean                      127
# watch_KaiinID_SaishuppinKaisuu_mean                 148
# watch_KaiinID_SaishuppinKaisuu_std                  102
# watch_KaiinID_SaishuppinKaisuu_sum                  183
# watch_KaiinID_SankouKakaku_mean                     108
# watch_KaiinID_SankouKakaku_std                       77
# watch_KaiinID_SankouKakaku_sum                      137
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         167
# watch_KaiinID_rate_mean_to_SankouKakaku             149
# Auction_elapsed_days                                411
# Brand_elapsed_days                                   14
# Line_elapsed_days                                     0
# KaiinID_watch_elapsed_day_max                       122
# KaiinID_watch_elapsed_day_min                       177
# KaiinID_watch_elapsed_day_std                       249
# AuctionID_watch_elapsed_day_max                      93
# AuctionID_watch_elapsed_day_min                     334
# AuctionID_watch_elapsed_day_std                      74
# watch_BrandID_KaiinID_rate                          166
# BrandID_SankouKakaku                                170
# SankouKakaku_rate_to_BrandID                        126
# BrandID_target_mean                                 110
# GenreID_target_mean                                 190
# ##################
# CPU times: user 1min 28s, sys: 8.91 s, total: 1min 37s
# Wall time: 31.5 s

# %%
# 手元のデータセットでndcg計算
y_true = be.extract_target_actions(watch, bid, dset_to_period["valid_for_sub"])
sub = be.adjust_sub_form(y_true[["KaiinID"]].drop_duplicates(),
                      watch_vs_dataset.data[["KaiinID", "AuctionID", "pred"]].rename(columns={"pred":"score"}), drop=True
)
ndcg_score = be.calc_ndcg(y_true, sub)
print("ndcg_score : ", ndcg_score)
# Out:
# ndcg_score :  0.05488949924815673

# %%
# 手元のデータで最善の予測をした際の結果
y_true = extract_target_actions(watch, bid, dset_to_period["valid_for_sub"])
cheat_pred = be.get_cheat_pred(pd.concat([vs_private_dataset.data[["KaiinID", "AuctionID", "pred"]], vs_business_dataset.data[["KaiinID", "AuctionID", "pred"]]]), y_true)
cheat_sub = be.adjust_sub_form(y_true[["KaiinID"]].drop_duplicates(), cheat_pred, drop=True)
cheat_dcgs = calc_ndcg(y_true, cheat_sub)
cheat_dcgs = cheat_dcgs.reset_index()

# %%
# 各データのdcg確認
# 手元のデータセットでndcg計算
y_true = be.extract_target_actions(watch, bid, dset_to_period["valid_for_sub"])
sub = be.adjust_sub_form(y_true[["KaiinID"]].drop_duplicates(),
                      watch_vs_dataset.data[["KaiinID", "AuctionID", "pred"]].rename(columns={"pred":"score"}), drop=True
)
dcgs = calc_ndcg(y_true, sub)
dcgs = dcgs.reset_index()

# %%
dcg_infos = (
    dcgs.merge(watch_cnt, on="KaiinID", how="left")
    .merge(bid_cnt, on="KaiinID", how="left")
    .merge(y_true.drop("AuctionID", axis=1).groupby("KaiinID", as_index=False).sum(), on="KaiinID", how="left")
    .merge(cheat_dcgs.rename(columns={"score": "cheat_score"}), on="KaiinID", how="left")
    .fillna(0)
)
print(dcg_infos.corr())
print(dcg_infos.query("score == 0").describe())
print(dcg_infos.query("score != 0").describe())
print(dcg_infos.query("(watch_cnt < 1000) & (bid_cnt < 50)").describe())
print(dcg_infos.query("(watch_cnt >= 1000) | (bid_cnt >= 50)").describe())
# Out:
#                  KaiinID     score  watch_cnt   bid_cnt  watch_actioned  \
# KaiinID         1.000000 -0.004682  -0.012328 -0.003893       -0.016975
# score          -0.004682  1.000000   0.052040  0.033016        0.046012
# watch_cnt      -0.012328  0.052040   1.000000  0.509239        0.622164
# bid_cnt        -0.003893  0.033016   0.509239  1.000000        0.325908
# watch_actioned -0.016975  0.046012   0.622164  0.325908        1.000000
# bid_actioned   -0.017098  0.081521   0.248743  0.616189        0.386692
# cheat_score    -0.006767  0.717838   0.288007  0.184718        0.258121
#
#                 bid_actioned  cheat_score
# KaiinID            -0.017098    -0.006767
# score               0.081521     0.717838
# watch_cnt           0.248743     0.288007
# bid_cnt             0.616189     0.184718
# watch_actioned      0.386692     0.258121
# bid_actioned        1.000000     0.238901
# cheat_score         0.238901     1.000000
#              KaiinID   score     watch_cnt      bid_cnt  watch_actioned  \
# count    4835.000000  4835.0   4835.000000  4835.000000     4835.000000
# mean   138575.200827     0.0    275.156774    34.715408        9.162151
# std     79399.625052     0.0    671.590428   126.442988       19.117588
# min        22.000000     0.0      0.000000     0.000000        0.000000
# 25%     68942.500000     0.0      7.000000     0.000000        1.000000
# 50%    140171.000000     0.0     75.000000     6.000000        3.000000
# 75%    205780.500000     0.0    291.500000    27.000000        9.000000
# max    277891.000000     0.0  19728.000000  3355.000000      345.000000
#
#        bid_actioned  cheat_score
# count   4835.000000  4835.000000
# mean       0.828542     0.038417
# std        3.358982     0.138849
# min        0.000000     0.000000
# 25%        0.000000     0.000000
# 50%        0.000000     0.000000
# 75%        1.000000     0.000000
# max      123.000000     1.000000
#              KaiinID        score     watch_cnt      bid_cnt  watch_actioned  \
# count    1509.000000  1509.000000   1509.000000  1509.000000     1509.000000
# mean   136447.779324     0.230761    765.820411   117.702452       27.018555
# std     78714.302425     0.218108   1735.010018   392.399778       56.877862
# min       173.000000     0.010955      0.000000     0.000000        0.000000
# 25%     71048.000000     0.080212     80.000000     6.000000        3.000000
# 50%    136086.000000     0.155970    270.000000    25.000000       11.000000
# 75%    200880.000000     0.302602    718.000000    78.000000       28.000000
# max    277803.000000     1.000000  24371.000000  5585.000000      820.000000
#
#        bid_actioned  cheat_score
# count   1509.000000  1509.000000
# mean       4.028496     0.529714
# std       10.541687     0.262323
# min        0.000000     0.056335
# 25%        0.000000     0.304540
# 50%        1.000000     0.503908
# 75%        4.000000     0.724967
# max      163.000000     1.000000
#              KaiinID        score    watch_cnt      bid_cnt  watch_actioned  \
# count    4906.000000  4906.000000  4906.000000  4906.000000     4906.000000
# mean   138287.207705     0.052560   132.263759     9.505911        8.164492
# std     79345.025250     0.153053   184.051822    12.235477       19.614014
# min        22.000000     0.000000     0.000000     0.000000        0.000000
# 25%     69279.750000     0.000000     6.000000     0.000000        1.000000
# 50%    138734.000000     0.000000    55.000000     4.000000        3.000000
# 75%    205016.250000     0.000000   181.000000    15.000000        8.000000
# max    277848.000000     1.000000   993.000000    49.000000      820.000000
#
#        bid_actioned  cheat_score
# count   4906.000000  4906.000000
# mean       0.756828     0.118852
# std        2.388253     0.254522
# min        0.000000     0.000000
# 25%        0.000000     0.000000
# 50%        0.000000     0.000000
# 75%        1.000000     0.000000
# max       86.000000     1.000000
#              KaiinID        score     watch_cnt      bid_cnt  watch_actioned  \
# count    1438.000000  1438.000000   1438.000000  1438.000000     1438.000000
# mean   137325.280946     0.062838   1277.552156   207.806676       31.303894
# std     78886.492811     0.111798   1933.449880   435.818150       56.143346
# min       237.000000     0.000000      0.000000     0.000000        0.000000
# 25%     69683.500000     0.000000    385.000000    62.000000        5.000000
# 50%    138998.000000     0.000000    731.000000    93.000000       14.000000
# 75%    202744.750000     0.091003   1404.000000   176.000000       36.000000
# max    277891.000000     1.000000  24371.000000  5585.000000      780.000000
#
#        bid_actioned  cheat_score
# count   1438.000000  1438.000000
# mean       4.431154     0.279554
# std       11.526095     0.298555
# min        0.000000     0.000000
# 25%        0.000000     0.000000
# 50%        1.000000     0.205092
# 75%        4.000000     0.515157
# max      163.000000     1.000000

# %%
tmp = lgb_rank.get_model_info(sampled_train)
tmp.sort_values("importance", ascending=False).head(30)

# %%
# %%time
# 予測値取得
dataset_pairs = [
    [watch_vs_dataset, watch_sub_dataset]
]

rank_params = {
    'objective': 'lambdarank',
    'metric': 'ndcg',
    "ndcg_at": 20,
    "nround": 500,
    "learning_rate": 0.01,
    "max_depth": 6,
    "num_leaves": 127,
    "num_iteration": 500
}

sample_flg = True

# 学習の様子可視化
for in_train_dataset, sub_dataset in dataset_pairs:

    # train test split
    train_dataset, test_dataset =be.DataSet.train_test_split(in_train_dataset)
    
    lgb_rank = LgbLambdaLank()    
    
    if sample_flg:
        sampled_train = be.DataSet.under_sampling(train_dataset, rate=10)

        # target encoding
        cat_cols = ["BrandID", "GenreID"]
        for cat_col in cat_cols:
            sampled_train.add_target_encode(cat_col=cat_col)
            be.target_encode_for_test(train_dataset=train_dataset, test_dataset=test_dataset, cat_col=cat_col)            
        lgb_rank.train(train_dataset=sampled_train, valid_dataset=test_dataset, desc=True)
    else:
        # target encoding
        cat_cols = ["BrandID", "GenreID"]
        for cat_col in cat_cols:
            train_dataset.add_target_encode(cat_col=cat_col)
            be.target_encode_for_test(train_dataset=train_dataset, test_dataset=test_dataset, cat_col=cat_col)    
        lgb_rank.train(train_dataset=train_dataset, valid_dataset=test_dataset, desc=True)        

    for cat_col in cat_cols:
        be.target_encode_for_test(train_dataset=in_train_dataset, test_dataset=sub_dataset, cat_col=cat_col)        
    sub_dataset.set_pred(lgb_rank.predict(sub_dataset))
# Out:
# [1]	valid_0's ndcg@20: 0.565636
# [2]	valid_0's ndcg@20: 0.576263
# [3]	valid_0's ndcg@20: 0.594657
# [4]	valid_0's ndcg@20: 0.598639
# [5]	valid_0's ndcg@20: 0.612305
# [6]	valid_0's ndcg@20: 0.612833
# [7]	valid_0's ndcg@20: 0.613805
# [8]	valid_0's ndcg@20: 0.614455
# [9]	valid_0's ndcg@20: 0.614003
# [10]	valid_0's ndcg@20: 0.61465
# [11]	valid_0's ndcg@20: 0.616131
# [12]	valid_0's ndcg@20: 0.618102
# [13]	valid_0's ndcg@20: 0.621269
# [14]	valid_0's ndcg@20: 0.622527
# [15]	valid_0's ndcg@20: 0.625764
# [16]	valid_0's ndcg@20: 0.626662
# [17]	valid_0's ndcg@20: 0.627856
# [18]	valid_0's ndcg@20: 0.629533
# [19]	valid_0's ndcg@20: 0.631363
# [20]	valid_0's ndcg@20: 0.631108
# [21]	valid_0's ndcg@20: 0.630578
# [22]	valid_0's ndcg@20: 0.632222
# [23]	valid_0's ndcg@20: 0.632136
# [24]	valid_0's ndcg@20: 0.632413
# [25]	valid_0's ndcg@20: 0.632302
# [26]	valid_0's ndcg@20: 0.632676
# [27]	valid_0's ndcg@20: 0.632572
# [28]	valid_0's ndcg@20: 0.632266
# [29]	valid_0's ndcg@20: 0.633787
# [30]	valid_0's ndcg@20: 0.633711
# [31]	valid_0's ndcg@20: 0.633623
# [32]	valid_0's ndcg@20: 0.634103
# [33]	valid_0's ndcg@20: 0.634421
# [34]	valid_0's ndcg@20: 0.635642
# [35]	valid_0's ndcg@20: 0.635996
# [36]	valid_0's ndcg@20: 0.636397
# [37]	valid_0's ndcg@20: 0.637396
# [38]	valid_0's ndcg@20: 0.637534
# [39]	valid_0's ndcg@20: 0.637971
# [40]	valid_0's ndcg@20: 0.638657
# [41]	valid_0's ndcg@20: 0.639053
# [42]	valid_0's ndcg@20: 0.639472
# [43]	valid_0's ndcg@20: 0.640353
# [44]	valid_0's ndcg@20: 0.641077
# [45]	valid_0's ndcg@20: 0.642293
# [46]	valid_0's ndcg@20: 0.643696
# [47]	valid_0's ndcg@20: 0.644667
# [48]	valid_0's ndcg@20: 0.645676
# [49]	valid_0's ndcg@20: 0.646143
# [50]	valid_0's ndcg@20: 0.646551
# [51]	valid_0's ndcg@20: 0.64746
# [52]	valid_0's ndcg@20: 0.647836
# [53]	valid_0's ndcg@20: 0.64821
# [54]	valid_0's ndcg@20: 0.649045
# [55]	valid_0's ndcg@20: 0.649123
# [56]	valid_0's ndcg@20: 0.64961
# [57]	valid_0's ndcg@20: 0.649579
# [58]	valid_0's ndcg@20: 0.649942
# [59]	valid_0's ndcg@20: 0.65001
# [60]	valid_0's ndcg@20: 0.650697
# [61]	valid_0's ndcg@20: 0.651477
# [62]	valid_0's ndcg@20: 0.652119
# [63]	valid_0's ndcg@20: 0.65187
# [64]	valid_0's ndcg@20: 0.652031
# [65]	valid_0's ndcg@20: 0.652784
# [66]	valid_0's ndcg@20: 0.652922
# [67]	valid_0's ndcg@20: 0.652758
# [68]	valid_0's ndcg@20: 0.653715
# [69]	valid_0's ndcg@20: 0.654131
# [70]	valid_0's ndcg@20: 0.654506
# [71]	valid_0's ndcg@20: 0.654654
# [72]	valid_0's ndcg@20: 0.654561
# [73]	valid_0's ndcg@20: 0.655067
# [74]	valid_0's ndcg@20: 0.655392
# [75]	valid_0's ndcg@20: 0.655071
# [76]	valid_0's ndcg@20: 0.655705
# [77]	valid_0's ndcg@20: 0.655727
# [78]	valid_0's ndcg@20: 0.655897
# [79]	valid_0's ndcg@20: 0.656031
# [80]	valid_0's ndcg@20: 0.655885
# [81]	valid_0's ndcg@20: 0.656199
# [82]	valid_0's ndcg@20: 0.656948
# [83]	valid_0's ndcg@20: 0.657041
# [84]	valid_0's ndcg@20: 0.657962
# [85]	valid_0's ndcg@20: 0.658299
# [86]	valid_0's ndcg@20: 0.659017
# [87]	valid_0's ndcg@20: 0.659588
# [88]	valid_0's ndcg@20: 0.659897
# [89]	valid_0's ndcg@20: 0.660471
# [90]	valid_0's ndcg@20: 0.660801
# [91]	valid_0's ndcg@20: 0.66113
# [92]	valid_0's ndcg@20: 0.66085
# [93]	valid_0's ndcg@20: 0.661415
# [94]	valid_0's ndcg@20: 0.661776
# [95]	valid_0's ndcg@20: 0.662187
# [96]	valid_0's ndcg@20: 0.662552
# [97]	valid_0's ndcg@20: 0.662866
# [98]	valid_0's ndcg@20: 0.663626
# [99]	valid_0's ndcg@20: 0.663991
# [100]	valid_0's ndcg@20: 0.664206
#
#
# ##################
#                                              importance
# SaishuppinKaisuu                                    276
# SankouKakaku                                        619
# watch_AuctionID_cnt                                 224
# watch_BrandID_cnt                                   124
# watch_ItemShouID_cnt                                  5
# watch_LineID_cnt                                      5
# watch_ShouhinID_cnt                                 138
# watch_ShouhinShubetsuID_cnt                           0
# watch_KaiinID_AuctionID_cnt_x                        28
# watch_KaiinID_BrandID_cnt                           173
# watch_KaiinID_ItemShouID_cnt                        204
# watch_KaiinID_LineID_cnt                             54
# watch_KaiinID_ShouhinID_cnt                         390
# watch_KaiinID_ShouhinShubetsuID_cnt                  84
# bid_AuctionID_cnt                                    29
# bid_BrandID_cnt                                     157
# bid_ItemShouID_cnt                                   51
# bid_ShouhinID_cnt                                    20
# bid_KaiinID_AuctionID_cnt                             9
# bid_KaiinID_BrandID_cnt                               7
# bid_KaiinID_ItemShouID_cnt                           32
# bid_KaiinID_LineID_cnt                               20
# bid_KaiinID_ShouhinID_cnt                           205
# bid_KaiinID_ShouhinShubetsuID_cnt                     9
# watch_KaiinID_AuctionID_cnt_y                       158
# watch_KaiinID_ConditionID_mean                       12
# watch_KaiinID_SaishuppinKaisuu_mean                  13
# watch_KaiinID_SaishuppinKaisuu_std                   12
# watch_KaiinID_SaishuppinKaisuu_sum                  166
# watch_KaiinID_SankouKakaku_mean                     200
# watch_KaiinID_SankouKakaku_std                      119
# watch_KaiinID_SankouKakaku_sum                      197
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         148
# watch_KaiinID_rate_mean_to_SankouKakaku             130
# Auction_elapsed_days                                648
# Brand_elapsed_days                                    0
# Line_elapsed_days                                     3
# KaiinID_watch_elapsed_day_max                        16
# KaiinID_watch_elapsed_day_min                        25
# KaiinID_watch_elapsed_day_std                        25
# AuctionID_watch_elapsed_day_max                     162
# AuctionID_watch_elapsed_day_min                     469
# AuctionID_watch_elapsed_day_std                      46
# watch_BrandID_KaiinID_rate                          330
# BrandID_SankouKakaku                                 27
# SankouKakaku_rate_to_BrandID                        145
# BrandID_target_mean                                 196
# GenreID_target_mean                                 160
# ##################
# CPU times: user 5min 18s, sys: 1min 6s, total: 6min 24s
# Wall time: 2min 50s

# %%
tmp = lgb_rank.get_model_info(sub_dataset)
tmp.sort_values("importance", ascending=False).head(30)
# Out:
#                                              importance
# Auction_elapsed_days                                648
# SankouKakaku                                        619
# AuctionID_watch_elapsed_day_min                     469
# watch_KaiinID_ShouhinID_cnt                         390
# watch_BrandID_KaiinID_rate                          330
# SaishuppinKaisuu                                    276
# watch_AuctionID_cnt                                 224
# bid_KaiinID_ShouhinID_cnt                           205
# watch_KaiinID_ItemShouID_cnt                        204
# watch_KaiinID_SankouKakaku_mean                     200
# watch_KaiinID_SankouKakaku_sum                      197
# BrandID_target_mean                                 196
# watch_KaiinID_BrandID_cnt                           173
# watch_KaiinID_SaishuppinKaisuu_sum                  166
# AuctionID_watch_elapsed_day_max                     162
# GenreID_target_mean                                 160
# watch_KaiinID_AuctionID_cnt_y                       158
# bid_BrandID_cnt                                     157
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         148
# SankouKakaku_rate_to_BrandID                        145
# watch_ShouhinID_cnt                                 138
# watch_KaiinID_rate_mean_to_SankouKakaku             130
# watch_BrandID_cnt                                   124
# watch_KaiinID_SankouKakaku_std                      119
# watch_KaiinID_ShouhinShubetsuID_cnt                  84
# watch_KaiinID_LineID_cnt                             54
# bid_ItemShouID_cnt                                   51
# AuctionID_watch_elapsed_day_std                      46
# bid_KaiinID_ItemShouID_cnt                           32
# bid_AuctionID_cnt                                    29

# %%
pred = watch_sub_dataset.data[["KaiinID", "AuctionID", "pred"]].rename(columns={"pred": "score"})
sub = adjust_sub_form(sub_users, pred, drop=True)
sub.to_csv(SUB_DIR + datetime.datetime.now().strftime("%Y%m%d%H%M") + "_submit.csv", index=False)
sub.head()
# Out:
#       KaiinID  AuctionID
# 259        24      93537
# 1571       24    4090309
# 1436       24    3345576
# 230        24      83252
# 640        24     475279

# %%
sub.drop_duplicates()
# Out:
#          KaiinID  AuctionID
# 33            24  3664401.0
# 20            24  2503413.0
# 1             24   111774.0
# 2             24   508537.0
# 3             24   596848.0
# ...          ...        ...
# 3603349   277891   607545.0
# 3603226   277891   234592.0
# 3603335   277891   564888.0
# 3603925   277891  2750836.0
# 3603333   277891   559335.0
#
# [120320 rows x 2 columns]

# %%
sub.shape
# Out:
# (120320, 2)

# %%
sub.groupby(["KaiinID", "AuctionID"]).size().reset_index().sort_values(0, ascending=False)
# Out:
#         KaiinID  AuctionID  0
# 66772    153257  3337329.0  2
# 30351     70083  2503413.0  2
# 90659    208911   111774.0  2
# 80209    184030  1757415.0  1
# 80220    184130   648018.0  1
# ...         ...        ... ..
# 40101     93650   508537.0  1
# 40100     93650   461819.0  1
# 40099     93650   111774.0  1
# 40098     93581  3647003.0  1
# 120316   277891  3469952.0  1
#
# [120317 rows x 3 columns]

# %%
# %%time
# アンサンブル
# watch学習

dataset_pairs = [
    [watch_vt_dataset, watch_vs_dataset]
]

# 学習の様子可視化
for in_train_dataset, sub_dataset in dataset_pairs:
    
    # train test split
    undersampled_datasets = [
        {"train_dataset": splited[0], "valid_dataset": splited[1]}
        for splited in 
        [be.DataSet.train_test_split(be.DataSet.under_sampling(in_train_dataset, rate=100))
        for _ in range(4)]
    ]
        
    # target encoding
#     cat_cols = ["BrandID", "GenreID"]
#     for cat_col in cat_cols:
#         sampled_train.add_target_encode(cat_col=cat_col)
#         be.target_encode_for_test(train_dataset=sampled_train, test_dataset=test_dataset, cat_col=cat_col)    
    
    models = be.DataEmsembler(LgbLambdaLank)
    models.train(undersampled_datasets)
    
    sub_dataset.set_pred(models.predict(sub_dataset))
# Out:
# [1]	valid_0's ndcg@20: 0.892296
# [2]	valid_0's ndcg@20: 0.900662
# [3]	valid_0's ndcg@20: 0.902642
# [4]	valid_0's ndcg@20: 0.902543
# [5]	valid_0's ndcg@20: 0.903634
# [6]	valid_0's ndcg@20: 0.90407
# [7]	valid_0's ndcg@20: 0.903476
# [8]	valid_0's ndcg@20: 0.906179
# [9]	valid_0's ndcg@20: 0.906513
# [10]	valid_0's ndcg@20: 0.906211
# [11]	valid_0's ndcg@20: 0.906645
# [12]	valid_0's ndcg@20: 0.906717
# [13]	valid_0's ndcg@20: 0.906789
# [14]	valid_0's ndcg@20: 0.906407
# [15]	valid_0's ndcg@20: 0.906738
# [16]	valid_0's ndcg@20: 0.907029
# [17]	valid_0's ndcg@20: 0.907427
# [18]	valid_0's ndcg@20: 0.907248
# [19]	valid_0's ndcg@20: 0.907019
# [20]	valid_0's ndcg@20: 0.907291
# [21]	valid_0's ndcg@20: 0.90717
# [22]	valid_0's ndcg@20: 0.907242
# [23]	valid_0's ndcg@20: 0.907145
# [24]	valid_0's ndcg@20: 0.907292
# [25]	valid_0's ndcg@20: 0.907445
# [26]	valid_0's ndcg@20: 0.907496
# [27]	valid_0's ndcg@20: 0.90757
# [28]	valid_0's ndcg@20: 0.90753
# [29]	valid_0's ndcg@20: 0.907704
# [30]	valid_0's ndcg@20: 0.907758
# [31]	valid_0's ndcg@20: 0.907878
# [32]	valid_0's ndcg@20: 0.907837
# [33]	valid_0's ndcg@20: 0.907823
# [34]	valid_0's ndcg@20: 0.907706
# [35]	valid_0's ndcg@20: 0.907708
# [36]	valid_0's ndcg@20: 0.907704
# [37]	valid_0's ndcg@20: 0.907625
# [38]	valid_0's ndcg@20: 0.907928
# [39]	valid_0's ndcg@20: 0.90802
# [40]	valid_0's ndcg@20: 0.907743
# [41]	valid_0's ndcg@20: 0.908106
# [42]	valid_0's ndcg@20: 0.908067
# [43]	valid_0's ndcg@20: 0.908176
# [44]	valid_0's ndcg@20: 0.908375
# [45]	valid_0's ndcg@20: 0.908366
# [46]	valid_0's ndcg@20: 0.908353
# [47]	valid_0's ndcg@20: 0.908248
# [48]	valid_0's ndcg@20: 0.908367
# [49]	valid_0's ndcg@20: 0.908412
# [50]	valid_0's ndcg@20: 0.908379
# [51]	valid_0's ndcg@20: 0.908551
# [52]	valid_0's ndcg@20: 0.908482
# [53]	valid_0's ndcg@20: 0.908379
# [54]	valid_0's ndcg@20: 0.908439
# [55]	valid_0's ndcg@20: 0.908411
# [56]	valid_0's ndcg@20: 0.908468
# [57]	valid_0's ndcg@20: 0.908586
# [58]	valid_0's ndcg@20: 0.908571
# [59]	valid_0's ndcg@20: 0.908578
# [60]	valid_0's ndcg@20: 0.908508
# [61]	valid_0's ndcg@20: 0.908593
# [62]	valid_0's ndcg@20: 0.908707
# [63]	valid_0's ndcg@20: 0.90856
# [64]	valid_0's ndcg@20: 0.909017
# [65]	valid_0's ndcg@20: 0.908933
# [66]	valid_0's ndcg@20: 0.90924
# [67]	valid_0's ndcg@20: 0.909261
# [68]	valid_0's ndcg@20: 0.909285
# [69]	valid_0's ndcg@20: 0.909325
# [70]	valid_0's ndcg@20: 0.909194
# [71]	valid_0's ndcg@20: 0.909101
# [72]	valid_0's ndcg@20: 0.909165
# [73]	valid_0's ndcg@20: 0.909063
# [74]	valid_0's ndcg@20: 0.909121
# [75]	valid_0's ndcg@20: 0.909152
# [76]	valid_0's ndcg@20: 0.909331
# [77]	valid_0's ndcg@20: 0.909291
# [78]	valid_0's ndcg@20: 0.909349
# [79]	valid_0's ndcg@20: 0.909053
# [80]	valid_0's ndcg@20: 0.909394
# [81]	valid_0's ndcg@20: 0.909356
# [82]	valid_0's ndcg@20: 0.909295
# [83]	valid_0's ndcg@20: 0.909247
# [84]	valid_0's ndcg@20: 0.909305
# [85]	valid_0's ndcg@20: 0.908871
# [86]	valid_0's ndcg@20: 0.90896
# [87]	valid_0's ndcg@20: 0.909055
# [88]	valid_0's ndcg@20: 0.909327
# [89]	valid_0's ndcg@20: 0.909508
# [90]	valid_0's ndcg@20: 0.909592
# [91]	valid_0's ndcg@20: 0.909438
# [92]	valid_0's ndcg@20: 0.909519
# [93]	valid_0's ndcg@20: 0.909494
# [94]	valid_0's ndcg@20: 0.909454
# [95]	valid_0's ndcg@20: 0.909463
# [96]	valid_0's ndcg@20: 0.909427
# [97]	valid_0's ndcg@20: 0.909365
# [98]	valid_0's ndcg@20: 0.909348
# [99]	valid_0's ndcg@20: 0.909369
# [100]	valid_0's ndcg@20: 0.909594
#
#
# ##################
#                                              importance
# SaishuppinKaisuu                                    267
# SankouKakaku                                         92
# watch_AuctionID_cnt                                 119
# watch_BrandID_cnt                                   110
# watch_ItemShouID_cnt                                 86
# watch_LineID_cnt                                      0
# watch_ShouhinID_cnt                                 103
# watch_ShouhinShubetsuID_cnt                           2
# watch_KaiinID_AuctionID_cnt_x                       104
# watch_KaiinID_BrandID_cnt                           182
# watch_KaiinID_ItemShouID_cnt                        118
# watch_KaiinID_LineID_cnt                             73
# watch_KaiinID_ShouhinID_cnt                           4
# watch_KaiinID_ShouhinShubetsuID_cnt                  50
# bid_AuctionID_cnt                                   170
# bid_BrandID_cnt                                     150
# bid_ItemShouID_cnt                                   90
# bid_ShouhinID_cnt                                    93
# bid_KaiinID_AuctionID_cnt                             9
# bid_KaiinID_BrandID_cnt                              78
# bid_KaiinID_ItemShouID_cnt                           77
# bid_KaiinID_LineID_cnt                               87
# bid_KaiinID_ShouhinID_cnt                             1
# bid_KaiinID_ShouhinShubetsuID_cnt                    32
# watch_KaiinID_AuctionID_cnt_y                        57
# watch_KaiinID_ConditionID_mean                      114
# watch_KaiinID_SaishuppinKaisuu_mean                 141
# watch_KaiinID_SaishuppinKaisuu_std                  127
# watch_KaiinID_SaishuppinKaisuu_sum                  172
# watch_KaiinID_SankouKakaku_mean                     228
# watch_KaiinID_SankouKakaku_std                       62
# watch_KaiinID_SankouKakaku_sum                      241
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu          97
# watch_KaiinID_rate_mean_to_SankouKakaku              99
# Auction_elapsed_days                                426
# Brand_elapsed_days                                   32
# Line_elapsed_days                                     0
# KaiinID_watch_elapsed_day_max                        41
# KaiinID_watch_elapsed_day_min                        92
# KaiinID_watch_elapsed_day_std                       255
# AuctionID_watch_elapsed_day_max                     165
# AuctionID_watch_elapsed_day_min                     440
# AuctionID_watch_elapsed_day_std                      50
# watch_BrandID_KaiinID_rate                          169
# BrandID_SankouKakaku                                213
# SankouKakaku_rate_to_BrandID                        222
# BrandID_target_mean                                 245
# GenreID_target_mean                                 109
# ##################
# CPU times: user 1min 35s, sys: 8.48 s, total: 1min 43s
# Wall time: 29.7 s

# %%
# %%time
# bid学習

# 学習の様子可視化
for target, dataset in {"bid": bid_vs_dataset}.items():
    print(target)
    
    # train test split
    train_dataset, test_dataset =be.DataSet.train_test_split(dataset)
    sampled_train = be.DataSet.under_sampling(train_dataset)

    # target encoding
#     cat_cols = ["BrandID", "GenreID"]
#     # userも組み合わせる
#     for cat_col in cat_cols:
#         sampled_train.add_target_encode(cat_col=cat_col)
#         be.target_encode_for_test(train_dataset=sampled_train, test_dataset=test_dataset, cat_col=cat_col)    
    
    lgb_bi = be.LgbBinaryClassifier()
    lgb_bi.train(train_dataset=sampled_train, valid_dataset=test_dataset, desc=True)
# Out:
# bid
# [1]	valid_0's auc: 0.967723
# [2]	valid_0's auc: 0.969615
# [3]	valid_0's auc: 0.969867
# [4]	valid_0's auc: 0.97008
# [5]	valid_0's auc: 0.970028
# [6]	valid_0's auc: 0.970128
# [7]	valid_0's auc: 0.970536
# [8]	valid_0's auc: 0.970549
# [9]	valid_0's auc: 0.970813
# [10]	valid_0's auc: 0.970847
# [11]	valid_0's auc: 0.970968
# [12]	valid_0's auc: 0.971024
# [13]	valid_0's auc: 0.971418
# [14]	valid_0's auc: 0.971452
# [15]	valid_0's auc: 0.97176
# [16]	valid_0's auc: 0.971855
# [17]	valid_0's auc: 0.971855
# [18]	valid_0's auc: 0.971889
# [19]	valid_0's auc: 0.971999
# [20]	valid_0's auc: 0.972026
# [21]	valid_0's auc: 0.971983
# [22]	valid_0's auc: 0.972125
# [23]	valid_0's auc: 0.972186
# [24]	valid_0's auc: 0.97229
# [25]	valid_0's auc: 0.972349
# [26]	valid_0's auc: 0.972334
# [27]	valid_0's auc: 0.972438
# [28]	valid_0's auc: 0.971929
# [29]	valid_0's auc: 0.971969
# [30]	valid_0's auc: 0.971986
# [31]	valid_0's auc: 0.971998
# [32]	valid_0's auc: 0.97201
# [33]	valid_0's auc: 0.972008
# [34]	valid_0's auc: 0.97202
# [35]	valid_0's auc: 0.972181
# [36]	valid_0's auc: 0.972167
# [37]	valid_0's auc: 0.972205
# [38]	valid_0's auc: 0.972167
# [39]	valid_0's auc: 0.972162
# [40]	valid_0's auc: 0.972166
# [41]	valid_0's auc: 0.972186
# [42]	valid_0's auc: 0.972268
# [43]	valid_0's auc: 0.972289
# [44]	valid_0's auc: 0.972283
# [45]	valid_0's auc: 0.972333
# [46]	valid_0's auc: 0.972343
# [47]	valid_0's auc: 0.972371
# [48]	valid_0's auc: 0.972385
# [49]	valid_0's auc: 0.972411
# [50]	valid_0's auc: 0.9724
# [51]	valid_0's auc: 0.972377
# [52]	valid_0's auc: 0.972418
# [53]	valid_0's auc: 0.972416
# [54]	valid_0's auc: 0.972453
# [55]	valid_0's auc: 0.972453
# [56]	valid_0's auc: 0.972413
# [57]	valid_0's auc: 0.972494
# [58]	valid_0's auc: 0.972633
# [59]	valid_0's auc: 0.972716
# [60]	valid_0's auc: 0.972822
# [61]	valid_0's auc: 0.972886
# [62]	valid_0's auc: 0.97295
# [63]	valid_0's auc: 0.973007
# [64]	valid_0's auc: 0.973021
# [65]	valid_0's auc: 0.973093
# [66]	valid_0's auc: 0.973202
# [67]	valid_0's auc: 0.973231
# [68]	valid_0's auc: 0.973277
# [69]	valid_0's auc: 0.973311
# [70]	valid_0's auc: 0.97333
# [71]	valid_0's auc: 0.973366
# [72]	valid_0's auc: 0.973441
# [73]	valid_0's auc: 0.973463
# [74]	valid_0's auc: 0.9735
# [75]	valid_0's auc: 0.973536
# [76]	valid_0's auc: 0.973588
# [77]	valid_0's auc: 0.97429
# [78]	valid_0's auc: 0.974332
# [79]	valid_0's auc: 0.974396
# [80]	valid_0's auc: 0.974419
# [81]	valid_0's auc: 0.974603
# [82]	valid_0's auc: 0.974631
# [83]	valid_0's auc: 0.974702
# [84]	valid_0's auc: 0.974732
# [85]	valid_0's auc: 0.9748
# [86]	valid_0's auc: 0.974829
# [87]	valid_0's auc: 0.974878
# [88]	valid_0's auc: 0.97493
# [89]	valid_0's auc: 0.974945
# [90]	valid_0's auc: 0.974941
# [91]	valid_0's auc: 0.974958
# [92]	valid_0's auc: 0.974971
# [93]	valid_0's auc: 0.975002
# [94]	valid_0's auc: 0.975021
# [95]	valid_0's auc: 0.975027
# [96]	valid_0's auc: 0.975066
# [97]	valid_0's auc: 0.975076
# [98]	valid_0's auc: 0.975104
# [99]	valid_0's auc: 0.975118
# [100]	valid_0's auc: 0.975132
#
#
# ##################
#                                              importance
# SaishuppinKaisuu                                    402
# SankouKakaku                                        149
# watch_AuctionID_cnt                                  31
# watch_BrandID_cnt                                   245
# watch_ItemShouID_cnt                                 25
# watch_LineID_cnt                                      0
# watch_ShouhinID_cnt                                 341
# watch_ShouhinShubetsuID_cnt                           0
# watch_KaiinID_AuctionID_cnt_x                       103
# watch_KaiinID_BrandID_cnt                            39
# watch_KaiinID_ItemShouID_cnt                        160
# watch_KaiinID_LineID_cnt                             18
# watch_KaiinID_ShouhinID_cnt                           0
# watch_KaiinID_ShouhinShubetsuID_cnt                  38
# bid_AuctionID_cnt                                   203
# bid_BrandID_cnt                                      59
# bid_ItemShouID_cnt                                    1
# bid_ShouhinID_cnt                                    97
# bid_KaiinID_AuctionID_cnt                             4
# bid_KaiinID_BrandID_cnt                             194
# bid_KaiinID_ItemShouID_cnt                           26
# bid_KaiinID_LineID_cnt                              101
# bid_KaiinID_ShouhinID_cnt                            36
# bid_KaiinID_ShouhinShubetsuID_cnt                    50
# watch_KaiinID_AuctionID_cnt_y                        57
# watch_KaiinID_ConditionID_mean                       93
# watch_KaiinID_SaishuppinKaisuu_mean                  87
# watch_KaiinID_SaishuppinKaisuu_std                   28
# watch_KaiinID_SaishuppinKaisuu_sum                  108
# watch_KaiinID_SankouKakaku_mean                      25
# watch_KaiinID_SankouKakaku_std                       30
# watch_KaiinID_SankouKakaku_sum                       42
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu          46
# watch_KaiinID_rate_mean_to_SankouKakaku             168
# Auction_elapsed_days                                309
# Brand_elapsed_days                                   14
# Line_elapsed_days                                     0
# KaiinID_watch_elapsed_day_max                        21
# KaiinID_watch_elapsed_day_min                       270
# KaiinID_watch_elapsed_day_std                        46
# AuctionID_watch_elapsed_day_max                     302
# AuctionID_watch_elapsed_day_min                     650
# AuctionID_watch_elapsed_day_std                     193
# watch_BrandID_KaiinID_rate                           91
# BrandID_SankouKakaku                                370
# SankouKakaku_rate_to_BrandID                         60
# ##################
# CPU times: user 32.9 s, sys: 4.36 s, total: 37.3 s
# Wall time: 13.1 s

# %%
tmp = lgb_bi.get_model_info(sampled_train)
tmp.sort_values("importance", ascending=False).head(30)
# Out:
#                                              importance
# AuctionID_watch_elapsed_day_min                     650
# SaishuppinKaisuu                                    402
# BrandID_SankouKakaku                                370
# watch_ShouhinID_cnt                                 341
# Auction_elapsed_days                                309
# AuctionID_watch_elapsed_day_max                     302
# KaiinID_watch_elapsed_day_min                       270
# watch_BrandID_cnt                                   245
# bid_AuctionID_cnt                                   203
# bid_KaiinID_BrandID_cnt                             194
# AuctionID_watch_elapsed_day_std                     193
# watch_KaiinID_rate_mean_to_SankouKakaku             168
# watch_KaiinID_ItemShouID_cnt                        160
# SankouKakaku                                        149
# watch_KaiinID_SaishuppinKaisuu_sum                  108
# watch_KaiinID_AuctionID_cnt_x                       103
# bid_KaiinID_LineID_cnt                              101
# bid_ShouhinID_cnt                                    97
# watch_KaiinID_ConditionID_mean                       93
# watch_BrandID_KaiinID_rate                           91
# watch_KaiinID_SaishuppinKaisuu_mean                  87
# SankouKakaku_rate_to_BrandID                         60
# bid_BrandID_cnt                                      59
# watch_KaiinID_AuctionID_cnt_y                        57
# bid_KaiinID_ShouhinShubetsuID_cnt                    50
# KaiinID_watch_elapsed_day_std                        46
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu          46
# watch_KaiinID_SankouKakaku_sum                       42
# watch_KaiinID_BrandID_cnt                            39
# watch_KaiinID_ShouhinShubetsuID_cnt                  38

# %%
# %%time
# watch学習
# params = {
#     "objective": "binary",
#     'metric': 'binary_logloss',
#     "nround": 500,
#     "learning_rate": 0.01,
#     "max_depth": 6,
#     "num_leaves": 127
# }
# 学習の様子可視化
for target, dataset in {"watch": watch_vs_dataset}.items():
    print(target)
    
    # train test split
    train_dataset, test_dataset =be.DataSet.train_test_split(dataset)
    sampled_train = be.DataSet.under_sampling(train_dataset)

    # target encoding
    cat_cols = ["BrandID", "GenreID"]
    for cat_col in cat_cols:
        sampled_train.add_target_encode(cat_col=cat_col)
        be.target_encode_for_test(train_dataset=sampled_train, test_dataset=test_dataset, cat_col=cat_col)    
    
    lgb_bi = be.LgbBinaryClassifier()
    lgb_bi.train(train_dataset=sampled_train, valid_dataset=test_dataset, desc=True)
# Out:
# watch
# [1]	valid_0's auc: 0.952835
# [2]	valid_0's auc: 0.953211
# [3]	valid_0's auc: 0.956015
# [4]	valid_0's auc: 0.956183
# [5]	valid_0's auc: 0.956196
# [6]	valid_0's auc: 0.956116
# [7]	valid_0's auc: 0.956201
# [8]	valid_0's auc: 0.956405
# [9]	valid_0's auc: 0.956599
# [10]	valid_0's auc: 0.956641
# [11]	valid_0's auc: 0.956557
# [12]	valid_0's auc: 0.956557
# [13]	valid_0's auc: 0.956544
# [14]	valid_0's auc: 0.956488
# [15]	valid_0's auc: 0.956492
# [16]	valid_0's auc: 0.956395
# [17]	valid_0's auc: 0.956541
# [18]	valid_0's auc: 0.956532
# [19]	valid_0's auc: 0.956653
# [20]	valid_0's auc: 0.956694
# [21]	valid_0's auc: 0.956825
# [22]	valid_0's auc: 0.95692
# [23]	valid_0's auc: 0.957064
# [24]	valid_0's auc: 0.957152
# [25]	valid_0's auc: 0.957189
# [26]	valid_0's auc: 0.957338
# [27]	valid_0's auc: 0.957423
# [28]	valid_0's auc: 0.957503
# [29]	valid_0's auc: 0.95762
# [30]	valid_0's auc: 0.957656
# [31]	valid_0's auc: 0.957674
# [32]	valid_0's auc: 0.957747
# [33]	valid_0's auc: 0.957871
# [34]	valid_0's auc: 0.957904
# [35]	valid_0's auc: 0.957943
# [36]	valid_0's auc: 0.958001
# [37]	valid_0's auc: 0.958088
# [38]	valid_0's auc: 0.958101
# [39]	valid_0's auc: 0.958182
# [40]	valid_0's auc: 0.958166
# [41]	valid_0's auc: 0.95821
# [42]	valid_0's auc: 0.958317
# [43]	valid_0's auc: 0.958325
# [44]	valid_0's auc: 0.958361
# [45]	valid_0's auc: 0.958371
# [46]	valid_0's auc: 0.958404
# [47]	valid_0's auc: 0.958403
# [48]	valid_0's auc: 0.958417
# [49]	valid_0's auc: 0.958498
# [50]	valid_0's auc: 0.958546
# [51]	valid_0's auc: 0.958568
# [52]	valid_0's auc: 0.958564
# [53]	valid_0's auc: 0.958621
# [54]	valid_0's auc: 0.958619
# [55]	valid_0's auc: 0.95861
# [56]	valid_0's auc: 0.960262
# [57]	valid_0's auc: 0.96028
# [58]	valid_0's auc: 0.960303
# [59]	valid_0's auc: 0.960279
# [60]	valid_0's auc: 0.960315
# [61]	valid_0's auc: 0.960356
# [62]	valid_0's auc: 0.960386
# [63]	valid_0's auc: 0.960415
# [64]	valid_0's auc: 0.960399
# [65]	valid_0's auc: 0.960476
# [66]	valid_0's auc: 0.960522
# [67]	valid_0's auc: 0.960994
# [68]	valid_0's auc: 0.961048
# [69]	valid_0's auc: 0.961088
# [70]	valid_0's auc: 0.961161
# [71]	valid_0's auc: 0.961202
# [72]	valid_0's auc: 0.961335
# [73]	valid_0's auc: 0.96138
# [74]	valid_0's auc: 0.961466
# [75]	valid_0's auc: 0.961547
# [76]	valid_0's auc: 0.961626
# [77]	valid_0's auc: 0.961684
# [78]	valid_0's auc: 0.961762
# [79]	valid_0's auc: 0.961829
# [80]	valid_0's auc: 0.9619
# [81]	valid_0's auc: 0.961984
# [82]	valid_0's auc: 0.962049
# [83]	valid_0's auc: 0.962118
# [84]	valid_0's auc: 0.962168
# [85]	valid_0's auc: 0.962213
# [86]	valid_0's auc: 0.962272
# [87]	valid_0's auc: 0.962319
# [88]	valid_0's auc: 0.962353
# [89]	valid_0's auc: 0.962402
# [90]	valid_0's auc: 0.962452
# [91]	valid_0's auc: 0.962475
# [92]	valid_0's auc: 0.962513
# [93]	valid_0's auc: 0.962543
# [94]	valid_0's auc: 0.962575
# [95]	valid_0's auc: 0.962621
# [96]	valid_0's auc: 0.962646
# [97]	valid_0's auc: 0.962676
# [98]	valid_0's auc: 0.962711
# [99]	valid_0's auc: 0.962751
# [100]	valid_0's auc: 0.962776
#
#
# ##################
#                                              importance
# SaishuppinKaisuu                                    178
# SankouKakaku                                         96
# watch_AuctionID_cnt                                 103
# watch_BrandID_cnt                                    17
# watch_ItemShouID_cnt                                 23
# watch_LineID_cnt                                      0
# watch_ShouhinID_cnt                                  56
# watch_ShouhinShubetsuID_cnt                           0
# watch_KaiinID_AuctionID_cnt_x                       260
# watch_KaiinID_BrandID_cnt                           163
# watch_KaiinID_ItemShouID_cnt                         49
# watch_KaiinID_LineID_cnt                             51
# watch_KaiinID_ShouhinID_cnt                         165
# watch_KaiinID_ShouhinShubetsuID_cnt                  93
# bid_AuctionID_cnt                                   197
# bid_BrandID_cnt                                      77
# bid_ItemShouID_cnt                                   23
# bid_ShouhinID_cnt                                    23
# bid_KaiinID_AuctionID_cnt                             0
# bid_KaiinID_BrandID_cnt                              33
# bid_KaiinID_ItemShouID_cnt                           30
# bid_KaiinID_LineID_cnt                               86
# bid_KaiinID_ShouhinID_cnt                             1
# bid_KaiinID_ShouhinShubetsuID_cnt                    77
# watch_KaiinID_AuctionID_cnt_y                        98
# watch_KaiinID_ConditionID_mean                      108
# watch_KaiinID_SaishuppinKaisuu_mean                  91
# watch_KaiinID_SaishuppinKaisuu_std                  121
# watch_KaiinID_SaishuppinKaisuu_sum                  212
# watch_KaiinID_SankouKakaku_mean                      51
# watch_KaiinID_SankouKakaku_std                       97
# watch_KaiinID_SankouKakaku_sum                      160
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         160
# watch_KaiinID_rate_mean_to_SankouKakaku              58
# Auction_elapsed_days                                284
# Brand_elapsed_days                                    0
# Line_elapsed_days                                     0
# KaiinID_watch_elapsed_day_max                       144
# KaiinID_watch_elapsed_day_min                       162
# KaiinID_watch_elapsed_day_std                        83
# AuctionID_watch_elapsed_day_max                      40
# AuctionID_watch_elapsed_day_min                     420
# AuctionID_watch_elapsed_day_std                      76
# watch_BrandID_KaiinID_rate                          150
# BrandID_SankouKakaku                                147
# SankouKakaku_rate_to_BrandID                         42
# BrandID_target_mean                                 323
# GenreID_target_mean                                  66
# ##################
# CPU times: user 33.2 s, sys: 4.18 s, total: 37.4 s
# Wall time: 12.3 s

# %%
tmp = lgb_bi.get_model_info(sampled_train)
tmp.sort_values("importance", ascending=False).head(30)
# Out:
#                                              importance
# AuctionID_watch_elapsed_day_min                     420
# BrandID_target_mean                                 323
# Auction_elapsed_days                                284
# watch_KaiinID_AuctionID_cnt_x                       260
# watch_KaiinID_SaishuppinKaisuu_sum                  212
# bid_AuctionID_cnt                                   197
# SaishuppinKaisuu                                    178
# watch_KaiinID_ShouhinID_cnt                         165
# watch_KaiinID_BrandID_cnt                           163
# KaiinID_watch_elapsed_day_min                       162
# watch_KaiinID_rate_mean_to_SaishuppinKaisuu         160
# watch_KaiinID_SankouKakaku_sum                      160
# watch_BrandID_KaiinID_rate                          150
# BrandID_SankouKakaku                                147
# KaiinID_watch_elapsed_day_max                       144
# watch_KaiinID_SaishuppinKaisuu_std                  121
# watch_KaiinID_ConditionID_mean                      108
# watch_AuctionID_cnt                                 103
# watch_KaiinID_AuctionID_cnt_y                        98
# watch_KaiinID_SankouKakaku_std                       97
# SankouKakaku                                         96
# watch_KaiinID_ShouhinShubetsuID_cnt                  93
# watch_KaiinID_SaishuppinKaisuu_mean                  91
# bid_KaiinID_LineID_cnt                               86
# KaiinID_watch_elapsed_day_std                        83
# bid_KaiinID_ShouhinShubetsuID_cnt                    77
# bid_BrandID_cnt                                      77
# AuctionID_watch_elapsed_day_std                      76
# GenreID_target_mean                                  66
# watch_KaiinID_rate_mean_to_SankouKakaku              58
